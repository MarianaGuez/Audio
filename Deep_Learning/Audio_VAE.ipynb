# %% [markdown]
# #Install libraries

# %%
# !pip install -q torchinfo
# !pip install einops
# !pip install datasets
# Out:
# Collecting einops
#   Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 633.5 kB/s eta 0:00:00
# Installing collected packages: einops
# Successfully installed einops-0.8.0
# Collecting datasets
#   Downloading datasets-2.20.0-py3-none-any.whl (547 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Collecting requests>=2.32.2 (from datasets)
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.4)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.5 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.5.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.7.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, requests, pyarrow, dill, multiprocess, datasets
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# Successfully installed datasets-2.20.0 dill-0.3.8 multiprocess-0.70.16 pyarrow-17.0.0 requests-2.32.3 xxhash-3.4.1

# %%
from datasets import load_dataset

# %%
import librosa

# %%
import soundfile as sf

# %%
from torch.utils.data import Dataset, DataLoader

# %%
from torchvision import transforms
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from torchinfo import summary
from einops import rearrange, repeat
import os
import pickle
import random

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import pickle
import librosa

# %%
from IPython.display import Audio

# %% [markdown]
# #Audio files pre-processing

# %%
# !unzip /content/drive/MyDrive/Data_AudioGen/recordings.zip -d /content/Audios
# Out:
# Archive:  /content/drive/MyDrive/Data_AudioGen/recordings.zip
#    creating: /content/Audios/recordings/
#   inflating: /content/Audios/recordings/0_george_10.wav
#   inflating: /content/Audios/recordings/0_george_14.wav
#   inflating: /content/Audios/recordings/0_george_20.wav
#   inflating: /content/Audios/recordings/0_george_22.wav
#   inflating: /content/Audios/recordings/0_george_28.wav
#   inflating: /content/Audios/recordings/0_george_30.wav
#   inflating: /content/Audios/recordings/0_george_31.wav
#   inflating: /content/Audios/recordings/0_george_32.wav
#   inflating: /content/Audios/recordings/0_george_34.wav
#   inflating: /content/Audios/recordings/0_george_38.wav
#   inflating: /content/Audios/recordings/0_george_39.wav
#   inflating: /content/Audios/recordings/0_george_42.wav
#   inflating: /content/Audios/recordings/0_george_45.wav
#   inflating: /content/Audios/recordings/0_george_49.wav
#   inflating: /content/Audios/recordings/0_george_9.wav
#   inflating: /content/Audios/recordings/0_jackson_1.wav
#   inflating: /content/Audios/recordings/0_jackson_10.wav
#   inflating: /content/Audios/recordings/0_jackson_11.wav
#   inflating: /content/Audios/recordings/0_jackson_14.wav
#   inflating: /content/Audios/recordings/0_jackson_15.wav
#   inflating: /content/Audios/recordings/0_jackson_18.wav
#   inflating: /content/Audios/recordings/0_jackson_27.wav
#   inflating: /content/Audios/recordings/0_jackson_34.wav
#   inflating: /content/Audios/recordings/0_jackson_35.wav
#   inflating: /content/Audios/recordings/0_jackson_36.wav
#   inflating: /content/Audios/recordings/0_jackson_40.wav
#   inflating: /content/Audios/recordings/0_jackson_42.wav
#   inflating: /content/Audios/recordings/0_jackson_46.wav
#   inflating: /content/Audios/recordings/0_jackson_47.wav
#   inflating: /content/Audios/recordings/0_jackson_5.wav
#   inflating: /content/Audios/recordings/0_jackson_6.wav
#   inflating: /content/Audios/recordings/0_jackson_9.wav
#   inflating: /content/Audios/recordings/0_lucas_0.wav
#   inflating: /content/Audios/recordings/0_lucas_11.wav
#   inflating: /content/Audios/recordings/0_lucas_12.wav
#   inflating: /content/Audios/recordings/0_lucas_14.wav
#   inflating: /content/Audios/recordings/0_lucas_19.wav
#   inflating: /content/Audios/recordings/0_lucas_27.wav
#   inflating: /content/Audios/recordings/0_lucas_3.wav
#   inflating: /content/Audios/recordings/0_lucas_30.wav
#   inflating: /content/Audios/recordings/0_lucas_32.wav
#   inflating: /content/Audios/recordings/0_lucas_38.wav
#   inflating: /content/Audios/recordings/0_lucas_41.wav
#   inflating: /content/Audios/recordings/0_lucas_46.wav
#   inflating: /content/Audios/recordings/0_lucas_48.wav
#   inflating: /content/Audios/recordings/0_lucas_49.wav
#   inflating: /content/Audios/recordings/0_lucas_6.wav
#   inflating: /content/Audios/recordings/0_lucas_7.wav
#   inflating: /content/Audios/recordings/0_lucas_8.wav
#   inflating: /content/Audios/recordings/0_nicolas_1.wav
#   inflating: /content/Audios/recordings/0_nicolas_12.wav
#   inflating: /content/Audios/recordings/0_nicolas_14.wav
#   inflating: /content/Audios/recordings/0_nicolas_15.wav
#   inflating: /content/Audios/recordings/0_nicolas_16.wav
#   inflating: /content/Audios/recordings/0_nicolas_18.wav
#   inflating: /content/Audios/recordings/0_nicolas_20.wav
#   inflating: /content/Audios/recordings/0_nicolas_21.wav
#   inflating: /content/Audios/recordings/0_nicolas_24.wav
#   inflating: /content/Audios/recordings/0_nicolas_29.wav
#   inflating: /content/Audios/recordings/0_nicolas_3.wav
#   inflating: /content/Audios/recordings/0_nicolas_39.wav
#   inflating: /content/Audios/recordings/0_nicolas_41.wav
#   inflating: /content/Audios/recordings/0_nicolas_42.wav
#   inflating: /content/Audios/recordings/0_nicolas_49.wav
#   inflating: /content/Audios/recordings/0_nicolas_7.wav
#   inflating: /content/Audios/recordings/0_theo_10.wav
#   inflating: /content/Audios/recordings/0_theo_11.wav
#   inflating: /content/Audios/recordings/0_theo_14.wav
#   inflating: /content/Audios/recordings/0_theo_2.wav
#   inflating: /content/Audios/recordings/0_theo_26.wav
#   inflating: /content/Audios/recordings/0_theo_27.wav
#   inflating: /content/Audios/recordings/0_theo_28.wav
#   inflating: /content/Audios/recordings/0_theo_29.wav
#   inflating: /content/Audios/recordings/0_theo_32.wav
#   inflating: /content/Audios/recordings/0_theo_38.wav
#   inflating: /content/Audios/recordings/0_theo_41.wav
#   inflating: /content/Audios/recordings/0_theo_43.wav
#   inflating: /content/Audios/recordings/0_theo_46.wav
#   inflating: /content/Audios/recordings/0_theo_48.wav
#   inflating: /content/Audios/recordings/0_theo_5.wav
#   inflating: /content/Audios/recordings/0_theo_6.wav
#   inflating: /content/Audios/recordings/0_yweweler_10.wav
#   inflating: /content/Audios/recordings/0_yweweler_13.wav
#   inflating: /content/Audios/recordings/0_yweweler_14.wav
#   inflating: /content/Audios/recordings/0_yweweler_15.wav
#   inflating: /content/Audios/recordings/0_yweweler_18.wav
#   inflating: /content/Audios/recordings/0_yweweler_2.wav
#   inflating: /content/Audios/recordings/0_yweweler_25.wav
#   inflating: /content/Audios/recordings/0_yweweler_26.wav
#   inflating: /content/Audios/recordings/0_yweweler_28.wav
#   inflating: /content/Audios/recordings/0_yweweler_29.wav
#   inflating: /content/Audios/recordings/0_yweweler_34.wav
#   inflating: /content/Audios/recordings/0_yweweler_37.wav
#   inflating: /content/Audios/recordings/0_yweweler_42.wav
#   inflating: /content/Audios/recordings/0_yweweler_6.wav
#   inflating: /content/Audios/recordings/0_yweweler_7.wav
#   inflating: /content/Audios/recordings/0_yweweler_8.wav
#   inflating: /content/Audios/recordings/1_george_0.wav
#   inflating: /content/Audios/recordings/1_george_1.wav
#   inflating: /content/Audios/recordings/1_george_10.wav
#   inflating: /content/Audios/recordings/1_george_18.wav
#   inflating: /content/Audios/recordings/1_george_2.wav
#   inflating: /content/Audios/recordings/1_george_21.wav
#   inflating: /content/Audios/recordings/1_george_24.wav
#   inflating: /content/Audios/recordings/1_george_31.wav
#   inflating: /content/Audios/recordings/1_george_36.wav
#   inflating: /content/Audios/recordings/1_george_38.wav
#   inflating: /content/Audios/recordings/1_george_42.wav
#   inflating: /content/Audios/recordings/1_george_48.wav
#   inflating: /content/Audios/recordings/1_george_5.wav
#   inflating: /content/Audios/recordings/1_jackson_15.wav
#   inflating: /content/Audios/recordings/1_jackson_23.wav
#   inflating: /content/Audios/recordings/1_jackson_25.wav
#   inflating: /content/Audios/recordings/1_jackson_28.wav
#   inflating: /content/Audios/recordings/1_jackson_29.wav
#   inflating: /content/Audios/recordings/1_jackson_30.wav
#   inflating: /content/Audios/recordings/1_jackson_31.wav
#   inflating: /content/Audios/recordings/1_jackson_34.wav
#   inflating: /content/Audios/recordings/1_jackson_36.wav
#   inflating: /content/Audios/recordings/1_jackson_4.wav
#   inflating: /content/Audios/recordings/1_jackson_46.wav
#   inflating: /content/Audios/recordings/1_jackson_6.wav
#   inflating: /content/Audios/recordings/1_jackson_8.wav
#   inflating: /content/Audios/recordings/1_lucas_10.wav
#   inflating: /content/Audios/recordings/1_lucas_11.wav
#   inflating: /content/Audios/recordings/1_lucas_14.wav
#   inflating: /content/Audios/recordings/1_lucas_15.wav
#   inflating: /content/Audios/recordings/1_lucas_16.wav
#   inflating: /content/Audios/recordings/1_lucas_18.wav
#   inflating: /content/Audios/recordings/1_lucas_24.wav
#   inflating: /content/Audios/recordings/1_lucas_25.wav
#   inflating: /content/Audios/recordings/1_lucas_3.wav
#   inflating: /content/Audios/recordings/1_lucas_32.wav
#   inflating: /content/Audios/recordings/1_lucas_37.wav
#   inflating: /content/Audios/recordings/1_lucas_4.wav
#   inflating: /content/Audios/recordings/1_lucas_40.wav
#   inflating: /content/Audios/recordings/1_lucas_46.wav
#   inflating: /content/Audios/recordings/1_lucas_47.wav
#   inflating: /content/Audios/recordings/1_lucas_5.wav
#   inflating: /content/Audios/recordings/1_lucas_8.wav
#   inflating: /content/Audios/recordings/1_lucas_9.wav
#   inflating: /content/Audios/recordings/1_nicolas_0.wav
#   inflating: /content/Audios/recordings/1_nicolas_1.wav
#   inflating: /content/Audios/recordings/1_nicolas_11.wav
#   inflating: /content/Audios/recordings/1_nicolas_12.wav
#   inflating: /content/Audios/recordings/1_nicolas_16.wav
#   inflating: /content/Audios/recordings/1_nicolas_17.wav
#   inflating: /content/Audios/recordings/1_nicolas_21.wav
#   inflating: /content/Audios/recordings/1_nicolas_22.wav
#   inflating: /content/Audios/recordings/1_nicolas_23.wav
#   inflating: /content/Audios/recordings/1_nicolas_27.wav
#   inflating: /content/Audios/recordings/1_nicolas_30.wav
#   inflating: /content/Audios/recordings/1_nicolas_32.wav
#   inflating: /content/Audios/recordings/1_nicolas_33.wav
#   inflating: /content/Audios/recordings/1_nicolas_34.wav
#   inflating: /content/Audios/recordings/1_nicolas_35.wav
#   inflating: /content/Audios/recordings/1_nicolas_36.wav
#   inflating: /content/Audios/recordings/1_nicolas_37.wav
#   inflating: /content/Audios/recordings/1_nicolas_40.wav
#   inflating: /content/Audios/recordings/1_nicolas_42.wav
#   inflating: /content/Audios/recordings/1_nicolas_43.wav
#   inflating: /content/Audios/recordings/1_nicolas_44.wav
#   inflating: /content/Audios/recordings/1_nicolas_48.wav
#   inflating: /content/Audios/recordings/1_nicolas_6.wav
#   inflating: /content/Audios/recordings/1_nicolas_8.wav
#   inflating: /content/Audios/recordings/1_nicolas_9.wav
#   inflating: /content/Audios/recordings/1_theo_0.wav
#   inflating: /content/Audios/recordings/1_theo_1.wav
#   inflating: /content/Audios/recordings/1_theo_11.wav
#   inflating: /content/Audios/recordings/1_theo_13.wav
#   inflating: /content/Audios/recordings/1_theo_14.wav
#   inflating: /content/Audios/recordings/1_theo_15.wav
#   inflating: /content/Audios/recordings/1_theo_16.wav
#   inflating: /content/Audios/recordings/1_theo_19.wav
#   inflating: /content/Audios/recordings/1_theo_20.wav
#   inflating: /content/Audios/recordings/1_theo_24.wav
#   inflating: /content/Audios/recordings/1_theo_26.wav
#   inflating: /content/Audios/recordings/1_theo_28.wav
#   inflating: /content/Audios/recordings/1_theo_32.wav
#   inflating: /content/Audios/recordings/1_theo_33.wav
#   inflating: /content/Audios/recordings/1_theo_34.wav
#   inflating: /content/Audios/recordings/1_theo_35.wav
#   inflating: /content/Audios/recordings/1_theo_39.wav
#   inflating: /content/Audios/recordings/1_theo_40.wav
#   inflating: /content/Audios/recordings/1_theo_46.wav
#   inflating: /content/Audios/recordings/1_theo_48.wav
#   inflating: /content/Audios/recordings/1_theo_5.wav
#   inflating: /content/Audios/recordings/1_theo_6.wav
#   inflating: /content/Audios/recordings/1_yweweler_10.wav
#   inflating: /content/Audios/recordings/1_yweweler_14.wav
#   inflating: /content/Audios/recordings/1_yweweler_17.wav
#   inflating: /content/Audios/recordings/1_yweweler_22.wav
#   inflating: /content/Audios/recordings/1_yweweler_3.wav
#   inflating: /content/Audios/recordings/1_yweweler_30.wav
#   inflating: /content/Audios/recordings/1_yweweler_31.wav
#   inflating: /content/Audios/recordings/1_yweweler_35.wav
#   inflating: /content/Audios/recordings/1_yweweler_36.wav
#   inflating: /content/Audios/recordings/1_yweweler_46.wav
#   inflating: /content/Audios/recordings/1_yweweler_47.wav
#   inflating: /content/Audios/recordings/1_yweweler_5.wav
#   inflating: /content/Audios/recordings/1_yweweler_7.wav
#   inflating: /content/Audios/recordings/1_yweweler_8.wav
#   inflating: /content/Audios/recordings/2_george_11.wav
#   inflating: /content/Audios/recordings/2_george_14.wav
#   inflating: /content/Audios/recordings/2_george_18.wav
#   inflating: /content/Audios/recordings/2_george_21.wav
#   inflating: /content/Audios/recordings/2_george_22.wav
#   inflating: /content/Audios/recordings/2_george_35.wav
#   inflating: /content/Audios/recordings/2_george_38.wav
#   inflating: /content/Audios/recordings/2_george_40.wav
#   inflating: /content/Audios/recordings/2_george_43.wav
#   inflating: /content/Audios/recordings/2_george_47.wav
#   inflating: /content/Audios/recordings/2_george_49.wav
#   inflating: /content/Audios/recordings/2_george_6.wav
#   inflating: /content/Audios/recordings/2_george_7.wav
#   inflating: /content/Audios/recordings/2_george_8.wav
#   inflating: /content/Audios/recordings/2_jackson_13.wav
#   inflating: /content/Audios/recordings/2_jackson_18.wav
#   inflating: /content/Audios/recordings/2_jackson_19.wav
#   inflating: /content/Audios/recordings/2_jackson_2.wav
#   inflating: /content/Audios/recordings/2_jackson_22.wav
#   inflating: /content/Audios/recordings/2_jackson_25.wav
#   inflating: /content/Audios/recordings/2_jackson_26.wav
#   inflating: /content/Audios/recordings/2_jackson_28.wav
#   inflating: /content/Audios/recordings/2_jackson_3.wav
#   inflating: /content/Audios/recordings/2_jackson_30.wav
#   inflating: /content/Audios/recordings/2_jackson_32.wav
#   inflating: /content/Audios/recordings/2_jackson_33.wav
#   inflating: /content/Audios/recordings/2_jackson_36.wav
#   inflating: /content/Audios/recordings/2_jackson_37.wav
#   inflating: /content/Audios/recordings/2_jackson_38.wav
#   inflating: /content/Audios/recordings/2_jackson_39.wav
#   inflating: /content/Audios/recordings/2_jackson_40.wav
#   inflating: /content/Audios/recordings/2_jackson_42.wav
#   inflating: /content/Audios/recordings/2_jackson_43.wav
#   inflating: /content/Audios/recordings/2_jackson_44.wav
#   inflating: /content/Audios/recordings/2_jackson_45.wav
#   inflating: /content/Audios/recordings/2_jackson_46.wav
#   inflating: /content/Audios/recordings/2_jackson_47.wav
#   inflating: /content/Audios/recordings/2_jackson_5.wav
#   inflating: /content/Audios/recordings/2_jackson_6.wav
#   inflating: /content/Audios/recordings/2_jackson_8.wav
#   inflating: /content/Audios/recordings/2_lucas_0.wav
#   inflating: /content/Audios/recordings/2_lucas_10.wav
#   inflating: /content/Audios/recordings/2_lucas_12.wav
#   inflating: /content/Audios/recordings/2_lucas_16.wav
#   inflating: /content/Audios/recordings/2_lucas_18.wav
#   inflating: /content/Audios/recordings/2_lucas_19.wav
#   inflating: /content/Audios/recordings/2_lucas_20.wav
#   inflating: /content/Audios/recordings/2_lucas_21.wav
#   inflating: /content/Audios/recordings/2_lucas_25.wav
#   inflating: /content/Audios/recordings/2_lucas_26.wav
#   inflating: /content/Audios/recordings/2_lucas_28.wav
#   inflating: /content/Audios/recordings/2_lucas_30.wav
#   inflating: /content/Audios/recordings/2_lucas_33.wav
#   inflating: /content/Audios/recordings/2_lucas_36.wav
#   inflating: /content/Audios/recordings/2_lucas_37.wav
#   inflating: /content/Audios/recordings/2_lucas_38.wav
#   inflating: /content/Audios/recordings/2_lucas_39.wav
#   inflating: /content/Audios/recordings/2_lucas_4.wav
#   inflating: /content/Audios/recordings/2_lucas_40.wav
#   inflating: /content/Audios/recordings/2_lucas_41.wav
#   inflating: /content/Audios/recordings/2_lucas_42.wav
#   inflating: /content/Audios/recordings/2_lucas_48.wav
#   inflating: /content/Audios/recordings/2_lucas_5.wav
#   inflating: /content/Audios/recordings/2_nicolas_1.wav
#   inflating: /content/Audios/recordings/2_nicolas_22.wav
#   inflating: /content/Audios/recordings/2_nicolas_24.wav
#   inflating: /content/Audios/recordings/2_nicolas_29.wav
#   inflating: /content/Audios/recordings/2_nicolas_3.wav
#   inflating: /content/Audios/recordings/2_nicolas_35.wav
#   inflating: /content/Audios/recordings/2_nicolas_36.wav
#   inflating: /content/Audios/recordings/2_nicolas_38.wav
#   inflating: /content/Audios/recordings/2_nicolas_39.wav
#   inflating: /content/Audios/recordings/2_nicolas_41.wav
#   inflating: /content/Audios/recordings/2_nicolas_7.wav
#   inflating: /content/Audios/recordings/2_theo_1.wav
#   inflating: /content/Audios/recordings/2_theo_14.wav
#   inflating: /content/Audios/recordings/2_theo_16.wav
#   inflating: /content/Audios/recordings/2_theo_19.wav
#   inflating: /content/Audios/recordings/2_theo_2.wav
#   inflating: /content/Audios/recordings/2_theo_22.wav
#   inflating: /content/Audios/recordings/2_theo_23.wav
#   inflating: /content/Audios/recordings/2_theo_26.wav
#   inflating: /content/Audios/recordings/2_theo_29.wav
#   inflating: /content/Audios/recordings/2_theo_31.wav
#   inflating: /content/Audios/recordings/2_theo_35.wav
#   inflating: /content/Audios/recordings/2_theo_38.wav
#   inflating: /content/Audios/recordings/2_theo_39.wav
#   inflating: /content/Audios/recordings/2_theo_4.wav
#   inflating: /content/Audios/recordings/2_theo_42.wav
#   inflating: /content/Audios/recordings/2_theo_43.wav
#   inflating: /content/Audios/recordings/2_theo_46.wav
#   inflating: /content/Audios/recordings/2_theo_5.wav
#   inflating: /content/Audios/recordings/2_theo_7.wav
#   inflating: /content/Audios/recordings/2_yweweler_10.wav
#   inflating: /content/Audios/recordings/2_yweweler_11.wav
#   inflating: /content/Audios/recordings/2_yweweler_12.wav
#   inflating: /content/Audios/recordings/2_yweweler_14.wav
#   inflating: /content/Audios/recordings/2_yweweler_17.wav
#   inflating: /content/Audios/recordings/2_yweweler_2.wav
#   inflating: /content/Audios/recordings/2_yweweler_21.wav
#   inflating: /content/Audios/recordings/2_yweweler_27.wav
#   inflating: /content/Audios/recordings/2_yweweler_28.wav
#   inflating: /content/Audios/recordings/2_yweweler_3.wav
#   inflating: /content/Audios/recordings/2_yweweler_30.wav
#   inflating: /content/Audios/recordings/2_yweweler_31.wav
#   inflating: /content/Audios/recordings/2_yweweler_32.wav
#   inflating: /content/Audios/recordings/2_yweweler_33.wav
#   inflating: /content/Audios/recordings/2_yweweler_35.wav
#   inflating: /content/Audios/recordings/2_yweweler_36.wav
#   inflating: /content/Audios/recordings/2_yweweler_44.wav
#   inflating: /content/Audios/recordings/2_yweweler_46.wav
#   inflating: /content/Audios/recordings/2_yweweler_47.wav
#   inflating: /content/Audios/recordings/2_yweweler_8.wav
#   inflating: /content/Audios/recordings/3_george_14.wav
#   inflating: /content/Audios/recordings/3_george_15.wav
#   inflating: /content/Audios/recordings/3_george_16.wav
#   inflating: /content/Audios/recordings/3_george_17.wav
#   inflating: /content/Audios/recordings/3_george_2.wav
#   inflating: /content/Audios/recordings/3_george_20.wav
#   inflating: /content/Audios/recordings/3_george_21.wav
#   inflating: /content/Audios/recordings/3_george_23.wav
#   inflating: /content/Audios/recordings/3_george_24.wav
#   inflating: /content/Audios/recordings/3_george_26.wav
#   inflating: /content/Audios/recordings/3_george_29.wav
#   inflating: /content/Audios/recordings/3_george_31.wav
#   inflating: /content/Audios/recordings/3_george_33.wav
#   inflating: /content/Audios/recordings/3_george_34.wav
#   inflating: /content/Audios/recordings/3_george_40.wav
#   inflating: /content/Audios/recordings/3_george_41.wav
#   inflating: /content/Audios/recordings/3_george_44.wav
#   inflating: /content/Audios/recordings/3_george_45.wav
#   inflating: /content/Audios/recordings/3_george_48.wav
#   inflating: /content/Audios/recordings/3_george_5.wav
#   inflating: /content/Audios/recordings/3_george_9.wav
#   inflating: /content/Audios/recordings/3_jackson_1.wav
#   inflating: /content/Audios/recordings/3_jackson_10.wav
#   inflating: /content/Audios/recordings/3_jackson_14.wav
#   inflating: /content/Audios/recordings/3_jackson_16.wav
#   inflating: /content/Audios/recordings/3_jackson_18.wav
#   inflating: /content/Audios/recordings/3_jackson_2.wav
#   inflating: /content/Audios/recordings/3_jackson_23.wav
#   inflating: /content/Audios/recordings/3_jackson_24.wav
#   inflating: /content/Audios/recordings/3_jackson_26.wav
#   inflating: /content/Audios/recordings/3_jackson_31.wav
#   inflating: /content/Audios/recordings/3_jackson_32.wav
#   inflating: /content/Audios/recordings/3_jackson_34.wav
#   inflating: /content/Audios/recordings/3_jackson_36.wav
#   inflating: /content/Audios/recordings/3_jackson_37.wav
#   inflating: /content/Audios/recordings/3_jackson_4.wav
#   inflating: /content/Audios/recordings/3_jackson_42.wav
#   inflating: /content/Audios/recordings/3_jackson_45.wav
#   inflating: /content/Audios/recordings/3_jackson_47.wav
#   inflating: /content/Audios/recordings/3_jackson_49.wav
#   inflating: /content/Audios/recordings/3_jackson_7.wav
#   inflating: /content/Audios/recordings/3_lucas_0.wav
#   inflating: /content/Audios/recordings/3_lucas_1.wav
#   inflating: /content/Audios/recordings/3_lucas_10.wav
#   inflating: /content/Audios/recordings/3_lucas_11.wav
#   inflating: /content/Audios/recordings/3_lucas_13.wav
#   inflating: /content/Audios/recordings/3_lucas_14.wav
#   inflating: /content/Audios/recordings/3_lucas_16.wav
#   inflating: /content/Audios/recordings/3_lucas_17.wav
#   inflating: /content/Audios/recordings/3_lucas_20.wav
#   inflating: /content/Audios/recordings/3_lucas_29.wav
#   inflating: /content/Audios/recordings/3_lucas_3.wav
#   inflating: /content/Audios/recordings/3_lucas_40.wav
#   inflating: /content/Audios/recordings/3_lucas_44.wav
#   inflating: /content/Audios/recordings/3_lucas_45.wav
#   inflating: /content/Audios/recordings/3_lucas_7.wav
#   inflating: /content/Audios/recordings/3_nicolas_0.wav
#   inflating: /content/Audios/recordings/3_nicolas_13.wav
#   inflating: /content/Audios/recordings/3_nicolas_15.wav
#   inflating: /content/Audios/recordings/3_nicolas_18.wav
#   inflating: /content/Audios/recordings/3_nicolas_20.wav
#   inflating: /content/Audios/recordings/3_nicolas_29.wav
#   inflating: /content/Audios/recordings/3_nicolas_31.wav
#   inflating: /content/Audios/recordings/3_nicolas_32.wav
#   inflating: /content/Audios/recordings/3_nicolas_34.wav
#   inflating: /content/Audios/recordings/3_nicolas_37.wav
#   inflating: /content/Audios/recordings/3_nicolas_8.wav
#   inflating: /content/Audios/recordings/3_nicolas_9.wav
#   inflating: /content/Audios/recordings/3_theo_11.wav
#   inflating: /content/Audios/recordings/3_theo_12.wav
#   inflating: /content/Audios/recordings/3_theo_15.wav
#   inflating: /content/Audios/recordings/3_theo_17.wav
#   inflating: /content/Audios/recordings/3_theo_25.wav
#   inflating: /content/Audios/recordings/3_theo_28.wav
#   inflating: /content/Audios/recordings/3_theo_32.wav
#   inflating: /content/Audios/recordings/3_theo_33.wav
#   inflating: /content/Audios/recordings/3_theo_41.wav
#   inflating: /content/Audios/recordings/3_theo_44.wav
#   inflating: /content/Audios/recordings/3_theo_5.wav
#   inflating: /content/Audios/recordings/3_yweweler_1.wav
#   inflating: /content/Audios/recordings/3_yweweler_10.wav
#   inflating: /content/Audios/recordings/3_yweweler_14.wav
#   inflating: /content/Audios/recordings/3_yweweler_15.wav
#   inflating: /content/Audios/recordings/3_yweweler_17.wav
#   inflating: /content/Audios/recordings/3_yweweler_18.wav
#   inflating: /content/Audios/recordings/3_yweweler_19.wav
#   inflating: /content/Audios/recordings/3_yweweler_2.wav
#   inflating: /content/Audios/recordings/3_yweweler_20.wav
#   inflating: /content/Audios/recordings/3_yweweler_22.wav
#   inflating: /content/Audios/recordings/3_yweweler_23.wav
#   inflating: /content/Audios/recordings/3_yweweler_27.wav
#   inflating: /content/Audios/recordings/3_yweweler_28.wav
#   inflating: /content/Audios/recordings/3_yweweler_29.wav
#   inflating: /content/Audios/recordings/3_yweweler_3.wav
#   inflating: /content/Audios/recordings/3_yweweler_31.wav
#   inflating: /content/Audios/recordings/3_yweweler_34.wav
#   inflating: /content/Audios/recordings/3_yweweler_37.wav
#   inflating: /content/Audios/recordings/3_yweweler_38.wav
#   inflating: /content/Audios/recordings/3_yweweler_39.wav
#   inflating: /content/Audios/recordings/3_yweweler_48.wav
#   inflating: /content/Audios/recordings/3_yweweler_9.wav
#   inflating: /content/Audios/recordings/4_george_0.wav
#   inflating: /content/Audios/recordings/4_george_1.wav
#   inflating: /content/Audios/recordings/4_george_10.wav
#   inflating: /content/Audios/recordings/4_george_17.wav
#   inflating: /content/Audios/recordings/4_george_21.wav
#   inflating: /content/Audios/recordings/4_george_22.wav
#   inflating: /content/Audios/recordings/4_george_23.wav
#   inflating: /content/Audios/recordings/4_george_28.wav
#   inflating: /content/Audios/recordings/4_george_29.wav
#   inflating: /content/Audios/recordings/4_george_36.wav
#   inflating: /content/Audios/recordings/4_george_42.wav
#   inflating: /content/Audios/recordings/4_george_43.wav
#   inflating: /content/Audios/recordings/4_george_45.wav
#   inflating: /content/Audios/recordings/4_george_46.wav
#   inflating: /content/Audios/recordings/4_george_49.wav
#   inflating: /content/Audios/recordings/4_george_5.wav
#   inflating: /content/Audios/recordings/4_george_6.wav
#   inflating: /content/Audios/recordings/4_jackson_10.wav
#   inflating: /content/Audios/recordings/4_jackson_11.wav
#   inflating: /content/Audios/recordings/4_jackson_2.wav
#   inflating: /content/Audios/recordings/4_jackson_20.wav
#   inflating: /content/Audios/recordings/4_jackson_24.wav
#   inflating: /content/Audios/recordings/4_jackson_25.wav
#   inflating: /content/Audios/recordings/4_jackson_26.wav
#   inflating: /content/Audios/recordings/4_jackson_3.wav
#   inflating: /content/Audios/recordings/4_jackson_30.wav
#   inflating: /content/Audios/recordings/4_jackson_35.wav
#   inflating: /content/Audios/recordings/4_jackson_38.wav
#   inflating: /content/Audios/recordings/4_jackson_39.wav
#   inflating: /content/Audios/recordings/4_jackson_43.wav
#   inflating: /content/Audios/recordings/4_jackson_45.wav
#   inflating: /content/Audios/recordings/4_jackson_46.wav
#   inflating: /content/Audios/recordings/4_jackson_48.wav
#   inflating: /content/Audios/recordings/4_jackson_8.wav
#   inflating: /content/Audios/recordings/4_jackson_9.wav
#   inflating: /content/Audios/recordings/4_lucas_1.wav
#   inflating: /content/Audios/recordings/4_lucas_15.wav
#   inflating: /content/Audios/recordings/4_lucas_17.wav
#   inflating: /content/Audios/recordings/4_lucas_19.wav
#   inflating: /content/Audios/recordings/4_lucas_22.wav
#   inflating: /content/Audios/recordings/4_lucas_26.wav
#   inflating: /content/Audios/recordings/4_lucas_28.wav
#   inflating: /content/Audios/recordings/4_lucas_3.wav
#   inflating: /content/Audios/recordings/4_lucas_30.wav
#   inflating: /content/Audios/recordings/4_lucas_34.wav
#   inflating: /content/Audios/recordings/4_lucas_35.wav
#   inflating: /content/Audios/recordings/4_lucas_37.wav
#   inflating: /content/Audios/recordings/4_lucas_4.wav
#   inflating: /content/Audios/recordings/4_lucas_43.wav
#   inflating: /content/Audios/recordings/4_lucas_7.wav
#   inflating: /content/Audios/recordings/4_nicolas_0.wav
#   inflating: /content/Audios/recordings/4_nicolas_12.wav
#   inflating: /content/Audios/recordings/4_nicolas_15.wav
#   inflating: /content/Audios/recordings/4_nicolas_17.wav
#   inflating: /content/Audios/recordings/4_nicolas_20.wav
#   inflating: /content/Audios/recordings/4_nicolas_23.wav
#   inflating: /content/Audios/recordings/4_nicolas_26.wav
#   inflating: /content/Audios/recordings/4_nicolas_29.wav
#   inflating: /content/Audios/recordings/4_nicolas_3.wav
#   inflating: /content/Audios/recordings/4_nicolas_30.wav
#   inflating: /content/Audios/recordings/4_nicolas_32.wav
#   inflating: /content/Audios/recordings/4_nicolas_38.wav
#   inflating: /content/Audios/recordings/4_nicolas_4.wav
#   inflating: /content/Audios/recordings/4_nicolas_41.wav
#   inflating: /content/Audios/recordings/4_nicolas_45.wav
#   inflating: /content/Audios/recordings/4_nicolas_46.wav
#   inflating: /content/Audios/recordings/4_nicolas_47.wav
#   inflating: /content/Audios/recordings/4_nicolas_49.wav
#   inflating: /content/Audios/recordings/4_nicolas_6.wav
#   inflating: /content/Audios/recordings/4_nicolas_7.wav
#   inflating: /content/Audios/recordings/4_nicolas_8.wav
#   inflating: /content/Audios/recordings/4_nicolas_9.wav
#   inflating: /content/Audios/recordings/4_theo_1.wav
#   inflating: /content/Audios/recordings/4_theo_16.wav
#   inflating: /content/Audios/recordings/4_theo_19.wav
#   inflating: /content/Audios/recordings/4_theo_26.wav
#   inflating: /content/Audios/recordings/4_theo_33.wav
#   inflating: /content/Audios/recordings/4_theo_36.wav
#   inflating: /content/Audios/recordings/4_theo_39.wav
#   inflating: /content/Audios/recordings/4_theo_40.wav
#   inflating: /content/Audios/recordings/4_theo_44.wav
#   inflating: /content/Audios/recordings/4_theo_49.wav
#   inflating: /content/Audios/recordings/4_theo_6.wav
#   inflating: /content/Audios/recordings/4_yweweler_1.wav
#   inflating: /content/Audios/recordings/4_yweweler_16.wav
#   inflating: /content/Audios/recordings/4_yweweler_24.wav
#   inflating: /content/Audios/recordings/4_yweweler_25.wav
#   inflating: /content/Audios/recordings/4_yweweler_26.wav
#   inflating: /content/Audios/recordings/4_yweweler_27.wav
#   inflating: /content/Audios/recordings/4_yweweler_28.wav
#   inflating: /content/Audios/recordings/4_yweweler_3.wav
#   inflating: /content/Audios/recordings/4_yweweler_30.wav
#   inflating: /content/Audios/recordings/4_yweweler_34.wav
#   inflating: /content/Audios/recordings/4_yweweler_38.wav
#   inflating: /content/Audios/recordings/4_yweweler_40.wav
#   inflating: /content/Audios/recordings/4_yweweler_46.wav
#   inflating: /content/Audios/recordings/5_george_10.wav
#   inflating: /content/Audios/recordings/5_george_19.wav
#   inflating: /content/Audios/recordings/5_george_20.wav
#   inflating: /content/Audios/recordings/5_george_21.wav
#   inflating: /content/Audios/recordings/5_george_22.wav
#   inflating: /content/Audios/recordings/5_george_27.wav
#   inflating: /content/Audios/recordings/5_george_30.wav
#   inflating: /content/Audios/recordings/5_george_4.wav
#   inflating: /content/Audios/recordings/5_george_42.wav
#   inflating: /content/Audios/recordings/5_george_43.wav
#   inflating: /content/Audios/recordings/5_george_44.wav
#   inflating: /content/Audios/recordings/5_george_48.wav
#   inflating: /content/Audios/recordings/5_george_5.wav
#   inflating: /content/Audios/recordings/5_george_8.wav
#   inflating: /content/Audios/recordings/5_jackson_0.wav
#   inflating: /content/Audios/recordings/5_jackson_1.wav
#   inflating: /content/Audios/recordings/5_jackson_11.wav
#   inflating: /content/Audios/recordings/5_jackson_12.wav
#   inflating: /content/Audios/recordings/5_jackson_25.wav
#   inflating: /content/Audios/recordings/5_jackson_26.wav
#   inflating: /content/Audios/recordings/5_jackson_30.wav
#   inflating: /content/Audios/recordings/5_jackson_31.wav
#   inflating: /content/Audios/recordings/5_jackson_32.wav
#   inflating: /content/Audios/recordings/5_jackson_35.wav
#   inflating: /content/Audios/recordings/5_jackson_39.wav
#   inflating: /content/Audios/recordings/5_jackson_40.wav
#   inflating: /content/Audios/recordings/5_jackson_43.wav
#   inflating: /content/Audios/recordings/5_jackson_9.wav
#   inflating: /content/Audios/recordings/5_lucas_11.wav
#   inflating: /content/Audios/recordings/5_lucas_15.wav
#   inflating: /content/Audios/recordings/5_lucas_21.wav
#   inflating: /content/Audios/recordings/5_lucas_22.wav
#   inflating: /content/Audios/recordings/5_lucas_25.wav
#   inflating: /content/Audios/recordings/5_lucas_28.wav
#   inflating: /content/Audios/recordings/5_lucas_3.wav
#   inflating: /content/Audios/recordings/5_lucas_34.wav
#   inflating: /content/Audios/recordings/5_lucas_36.wav
#   inflating: /content/Audios/recordings/5_lucas_38.wav
#   inflating: /content/Audios/recordings/5_lucas_43.wav
#   inflating: /content/Audios/recordings/5_lucas_46.wav
#   inflating: /content/Audios/recordings/5_nicolas_14.wav
#   inflating: /content/Audios/recordings/5_nicolas_2.wav
#   inflating: /content/Audios/recordings/5_nicolas_26.wav
#   inflating: /content/Audios/recordings/5_nicolas_28.wav
#   inflating: /content/Audios/recordings/5_nicolas_31.wav
#   inflating: /content/Audios/recordings/5_nicolas_37.wav
#   inflating: /content/Audios/recordings/5_nicolas_40.wav
#   inflating: /content/Audios/recordings/5_nicolas_42.wav
#   inflating: /content/Audios/recordings/5_nicolas_45.wav
#   inflating: /content/Audios/recordings/5_nicolas_46.wav
#   inflating: /content/Audios/recordings/5_nicolas_5.wav
#   inflating: /content/Audios/recordings/5_nicolas_6.wav
#   inflating: /content/Audios/recordings/5_nicolas_8.wav
#   inflating: /content/Audios/recordings/5_nicolas_9.wav
#   inflating: /content/Audios/recordings/5_theo_0.wav
#   inflating: /content/Audios/recordings/5_theo_1.wav
#   inflating: /content/Audios/recordings/5_theo_15.wav
#   inflating: /content/Audios/recordings/5_theo_16.wav
#   inflating: /content/Audios/recordings/5_theo_17.wav
#   inflating: /content/Audios/recordings/5_theo_23.wav
#   inflating: /content/Audios/recordings/5_theo_24.wav
#   inflating: /content/Audios/recordings/5_theo_25.wav
#   inflating: /content/Audios/recordings/5_theo_28.wav
#   inflating: /content/Audios/recordings/5_theo_31.wav
#   inflating: /content/Audios/recordings/5_theo_38.wav
#   inflating: /content/Audios/recordings/5_theo_39.wav
#   inflating: /content/Audios/recordings/5_theo_42.wav
#   inflating: /content/Audios/recordings/5_theo_47.wav
#   inflating: /content/Audios/recordings/5_theo_49.wav
#   inflating: /content/Audios/recordings/5_theo_7.wav
#   inflating: /content/Audios/recordings/5_theo_8.wav
#   inflating: /content/Audios/recordings/5_yweweler_1.wav
#   inflating: /content/Audios/recordings/5_yweweler_15.wav
#   inflating: /content/Audios/recordings/5_yweweler_17.wav
#   inflating: /content/Audios/recordings/5_yweweler_24.wav
#   inflating: /content/Audios/recordings/5_yweweler_25.wav
#   inflating: /content/Audios/recordings/5_yweweler_27.wav
#   inflating: /content/Audios/recordings/5_yweweler_32.wav
#   inflating: /content/Audios/recordings/5_yweweler_37.wav
#   inflating: /content/Audios/recordings/5_yweweler_43.wav
#   inflating: /content/Audios/recordings/5_yweweler_45.wav
#   inflating: /content/Audios/recordings/5_yweweler_47.wav
#   inflating: /content/Audios/recordings/5_yweweler_49.wav
#   inflating: /content/Audios/recordings/5_yweweler_5.wav
#   inflating: /content/Audios/recordings/5_yweweler_8.wav
#   inflating: /content/Audios/recordings/6_george_0.wav
#   inflating: /content/Audios/recordings/6_george_11.wav
#   inflating: /content/Audios/recordings/6_george_16.wav
#   inflating: /content/Audios/recordings/6_george_18.wav
#   inflating: /content/Audios/recordings/6_george_25.wav
#   inflating: /content/Audios/recordings/6_george_26.wav
#   inflating: /content/Audios/recordings/6_george_28.wav
#   inflating: /content/Audios/recordings/6_george_3.wav
#   inflating: /content/Audios/recordings/6_george_33.wav
#   inflating: /content/Audios/recordings/6_george_38.wav
#   inflating: /content/Audios/recordings/6_george_39.wav
#   inflating: /content/Audios/recordings/6_jackson_1.wav
#   inflating: /content/Audios/recordings/6_jackson_15.wav
#   inflating: /content/Audios/recordings/6_jackson_23.wav
#   inflating: /content/Audios/recordings/6_jackson_24.wav
#   inflating: /content/Audios/recordings/6_jackson_27.wav
#   inflating: /content/Audios/recordings/6_jackson_28.wav
#   inflating: /content/Audios/recordings/6_jackson_29.wav
#   inflating: /content/Audios/recordings/6_jackson_31.wav
#   inflating: /content/Audios/recordings/6_jackson_35.wav
#   inflating: /content/Audios/recordings/6_jackson_36.wav
#   inflating: /content/Audios/recordings/6_jackson_41.wav
#   inflating: /content/Audios/recordings/6_jackson_43.wav
#   inflating: /content/Audios/recordings/6_jackson_44.wav
#   inflating: /content/Audios/recordings/6_jackson_45.wav
#   inflating: /content/Audios/recordings/6_jackson_48.wav
#   inflating: /content/Audios/recordings/6_jackson_5.wav
#   inflating: /content/Audios/recordings/6_jackson_6.wav
#   inflating: /content/Audios/recordings/6_lucas_0.wav
#   inflating: /content/Audios/recordings/6_lucas_11.wav
#   inflating: /content/Audios/recordings/6_lucas_12.wav
#   inflating: /content/Audios/recordings/6_lucas_21.wav
#   inflating: /content/Audios/recordings/6_lucas_24.wav
#   inflating: /content/Audios/recordings/6_lucas_29.wav
#   inflating: /content/Audios/recordings/6_lucas_30.wav
#   inflating: /content/Audios/recordings/6_lucas_33.wav
#   inflating: /content/Audios/recordings/6_lucas_34.wav
#   inflating: /content/Audios/recordings/6_lucas_39.wav
#   inflating: /content/Audios/recordings/6_lucas_41.wav
#   inflating: /content/Audios/recordings/6_lucas_43.wav
#   inflating: /content/Audios/recordings/6_lucas_45.wav
#   inflating: /content/Audios/recordings/6_lucas_46.wav
#   inflating: /content/Audios/recordings/6_lucas_47.wav
#   inflating: /content/Audios/recordings/6_lucas_49.wav
#   inflating: /content/Audios/recordings/6_lucas_6.wav
#   inflating: /content/Audios/recordings/6_nicolas_0.wav
#   inflating: /content/Audios/recordings/6_nicolas_1.wav
#   inflating: /content/Audios/recordings/6_nicolas_13.wav
#   inflating: /content/Audios/recordings/6_nicolas_16.wav
#   inflating: /content/Audios/recordings/6_nicolas_17.wav
#   inflating: /content/Audios/recordings/6_nicolas_18.wav
#   inflating: /content/Audios/recordings/6_nicolas_2.wav
#   inflating: /content/Audios/recordings/6_nicolas_22.wav
#   inflating: /content/Audios/recordings/6_nicolas_23.wav
#   inflating: /content/Audios/recordings/6_nicolas_24.wav
#   inflating: /content/Audios/recordings/6_nicolas_26.wav
#   inflating: /content/Audios/recordings/6_nicolas_27.wav
#   inflating: /content/Audios/recordings/6_nicolas_29.wav
#   inflating: /content/Audios/recordings/6_nicolas_30.wav
#   inflating: /content/Audios/recordings/6_nicolas_31.wav
#   inflating: /content/Audios/recordings/6_nicolas_4.wav
#   inflating: /content/Audios/recordings/6_nicolas_40.wav
#   inflating: /content/Audios/recordings/6_nicolas_41.wav
#   inflating: /content/Audios/recordings/6_nicolas_43.wav
#   inflating: /content/Audios/recordings/6_nicolas_45.wav
#   inflating: /content/Audios/recordings/6_nicolas_5.wav
#   inflating: /content/Audios/recordings/6_nicolas_7.wav
#   inflating: /content/Audios/recordings/6_theo_11.wav
#   inflating: /content/Audios/recordings/6_theo_15.wav
#   inflating: /content/Audios/recordings/6_theo_16.wav
#   inflating: /content/Audios/recordings/6_theo_19.wav
#   inflating: /content/Audios/recordings/6_theo_21.wav
#   inflating: /content/Audios/recordings/6_theo_24.wav
#   inflating: /content/Audios/recordings/6_theo_31.wav
#   inflating: /content/Audios/recordings/6_theo_32.wav
#   inflating: /content/Audios/recordings/6_theo_35.wav
#   inflating: /content/Audios/recordings/6_theo_40.wav
#   inflating: /content/Audios/recordings/6_theo_48.wav
#   inflating: /content/Audios/recordings/6_theo_49.wav
#   inflating: /content/Audios/recordings/6_theo_8.wav
#   inflating: /content/Audios/recordings/6_yweweler_0.wav
#   inflating: /content/Audios/recordings/6_yweweler_12.wav
#   inflating: /content/Audios/recordings/6_yweweler_14.wav
#   inflating: /content/Audios/recordings/6_yweweler_16.wav
#   inflating: /content/Audios/recordings/6_yweweler_19.wav
#   inflating: /content/Audios/recordings/6_yweweler_2.wav
#   inflating: /content/Audios/recordings/6_yweweler_23.wav
#   inflating: /content/Audios/recordings/6_yweweler_28.wav
#   inflating: /content/Audios/recordings/6_yweweler_3.wav
#   inflating: /content/Audios/recordings/6_yweweler_30.wav
#   inflating: /content/Audios/recordings/6_yweweler_34.wav
#   inflating: /content/Audios/recordings/6_yweweler_36.wav
#   inflating: /content/Audios/recordings/6_yweweler_38.wav
#   inflating: /content/Audios/recordings/6_yweweler_41.wav
#   inflating: /content/Audios/recordings/6_yweweler_44.wav
#   inflating: /content/Audios/recordings/6_yweweler_45.wav
#   inflating: /content/Audios/recordings/6_yweweler_46.wav
#   inflating: /content/Audios/recordings/6_yweweler_47.wav
#   inflating: /content/Audios/recordings/7_george_18.wav
#   inflating: /content/Audios/recordings/7_george_20.wav
#   inflating: /content/Audios/recordings/7_george_22.wav
#   inflating: /content/Audios/recordings/7_george_23.wav
#   inflating: /content/Audios/recordings/7_george_27.wav
#   inflating: /content/Audios/recordings/7_george_28.wav
#   inflating: /content/Audios/recordings/7_george_31.wav
#   inflating: /content/Audios/recordings/7_george_32.wav
#   inflating: /content/Audios/recordings/7_george_33.wav
#   inflating: /content/Audios/recordings/7_george_34.wav
#   inflating: /content/Audios/recordings/7_george_35.wav
#   inflating: /content/Audios/recordings/7_george_43.wav
#   inflating: /content/Audios/recordings/7_george_45.wav
#   inflating: /content/Audios/recordings/7_george_49.wav
#   inflating: /content/Audios/recordings/7_george_7.wav
#   inflating: /content/Audios/recordings/7_jackson_11.wav
#   inflating: /content/Audios/recordings/7_jackson_12.wav
#   inflating: /content/Audios/recordings/7_jackson_18.wav
#   inflating: /content/Audios/recordings/7_jackson_19.wav
#   inflating: /content/Audios/recordings/7_jackson_22.wav
#   inflating: /content/Audios/recordings/7_jackson_25.wav
#   inflating: /content/Audios/recordings/7_jackson_28.wav
#   inflating: /content/Audios/recordings/7_jackson_30.wav
#   inflating: /content/Audios/recordings/7_jackson_37.wav
#   inflating: /content/Audios/recordings/7_jackson_39.wav
#   inflating: /content/Audios/recordings/7_jackson_40.wav
#   inflating: /content/Audios/recordings/7_jackson_42.wav
#   inflating: /content/Audios/recordings/7_jackson_43.wav
#   inflating: /content/Audios/recordings/7_jackson_44.wav
#   inflating: /content/Audios/recordings/7_jackson_45.wav
#   inflating: /content/Audios/recordings/7_jackson_49.wav
#   inflating: /content/Audios/recordings/7_jackson_9.wav
#   inflating: /content/Audios/recordings/7_lucas_1.wav
#   inflating: /content/Audios/recordings/7_lucas_10.wav
#   inflating: /content/Audios/recordings/7_lucas_16.wav
#   inflating: /content/Audios/recordings/7_lucas_18.wav
#   inflating: /content/Audios/recordings/7_lucas_2.wav
#   inflating: /content/Audios/recordings/7_lucas_21.wav
#   inflating: /content/Audios/recordings/7_lucas_25.wav
#   inflating: /content/Audios/recordings/7_lucas_26.wav
#   inflating: /content/Audios/recordings/7_lucas_33.wav
#   inflating: /content/Audios/recordings/7_lucas_38.wav
#   inflating: /content/Audios/recordings/7_lucas_4.wav
#   inflating: /content/Audios/recordings/7_lucas_46.wav
#   inflating: /content/Audios/recordings/7_lucas_48.wav
#   inflating: /content/Audios/recordings/7_lucas_7.wav
#   inflating: /content/Audios/recordings/7_lucas_9.wav
#   inflating: /content/Audios/recordings/7_nicolas_12.wav
#   inflating: /content/Audios/recordings/7_nicolas_16.wav
#   inflating: /content/Audios/recordings/7_nicolas_17.wav
#   inflating: /content/Audios/recordings/7_nicolas_18.wav
#   inflating: /content/Audios/recordings/7_nicolas_22.wav
#   inflating: /content/Audios/recordings/7_nicolas_23.wav
#   inflating: /content/Audios/recordings/7_nicolas_24.wav
#   inflating: /content/Audios/recordings/7_nicolas_25.wav
#   inflating: /content/Audios/recordings/7_nicolas_27.wav
#   inflating: /content/Audios/recordings/7_nicolas_28.wav
#   inflating: /content/Audios/recordings/7_nicolas_30.wav
#   inflating: /content/Audios/recordings/7_nicolas_31.wav
#   inflating: /content/Audios/recordings/7_nicolas_32.wav
#   inflating: /content/Audios/recordings/7_nicolas_33.wav
#   inflating: /content/Audios/recordings/7_nicolas_34.wav
#   inflating: /content/Audios/recordings/7_nicolas_35.wav
#   inflating: /content/Audios/recordings/7_nicolas_38.wav
#   inflating: /content/Audios/recordings/7_nicolas_39.wav
#   inflating: /content/Audios/recordings/7_nicolas_4.wav
#   inflating: /content/Audios/recordings/7_nicolas_42.wav
#   inflating: /content/Audios/recordings/7_nicolas_46.wav
#   inflating: /content/Audios/recordings/7_nicolas_47.wav
#   inflating: /content/Audios/recordings/7_nicolas_6.wav
#   inflating: /content/Audios/recordings/7_nicolas_9.wav
#   inflating: /content/Audios/recordings/7_theo_0.wav
#   inflating: /content/Audios/recordings/7_theo_11.wav
#   inflating: /content/Audios/recordings/7_theo_12.wav
#   inflating: /content/Audios/recordings/7_theo_13.wav
#   inflating: /content/Audios/recordings/7_theo_20.wav
#   inflating: /content/Audios/recordings/7_theo_22.wav
#   inflating: /content/Audios/recordings/7_theo_24.wav
#   inflating: /content/Audios/recordings/7_theo_25.wav
#   inflating: /content/Audios/recordings/7_theo_29.wav
#   inflating: /content/Audios/recordings/7_theo_34.wav
#   inflating: /content/Audios/recordings/7_theo_35.wav
#   inflating: /content/Audios/recordings/7_theo_38.wav
#   inflating: /content/Audios/recordings/7_theo_40.wav
#   inflating: /content/Audios/recordings/7_theo_41.wav
#   inflating: /content/Audios/recordings/7_theo_42.wav
#   inflating: /content/Audios/recordings/7_theo_43.wav
#   inflating: /content/Audios/recordings/7_theo_48.wav
#   inflating: /content/Audios/recordings/7_theo_7.wav
#   inflating: /content/Audios/recordings/7_theo_8.wav
#   inflating: /content/Audios/recordings/7_yweweler_1.wav
#   inflating: /content/Audios/recordings/7_yweweler_11.wav
#   inflating: /content/Audios/recordings/7_yweweler_13.wav
#   inflating: /content/Audios/recordings/7_yweweler_14.wav
#   inflating: /content/Audios/recordings/7_yweweler_15.wav
#   inflating: /content/Audios/recordings/7_yweweler_2.wav
#   inflating: /content/Audios/recordings/7_yweweler_21.wav
#   inflating: /content/Audios/recordings/7_yweweler_24.wav
#   inflating: /content/Audios/recordings/7_yweweler_25.wav
#   inflating: /content/Audios/recordings/7_yweweler_29.wav
#   inflating: /content/Audios/recordings/7_yweweler_3.wav
#   inflating: /content/Audios/recordings/7_yweweler_35.wav
#   inflating: /content/Audios/recordings/7_yweweler_38.wav
#   inflating: /content/Audios/recordings/7_yweweler_40.wav
#   inflating: /content/Audios/recordings/7_yweweler_45.wav
#   inflating: /content/Audios/recordings/7_yweweler_48.wav
#   inflating: /content/Audios/recordings/8_george_0.wav
#   inflating: /content/Audios/recordings/8_george_14.wav
#   inflating: /content/Audios/recordings/8_george_15.wav
#   inflating: /content/Audios/recordings/8_george_18.wav
#   inflating: /content/Audios/recordings/8_george_2.wav
#   inflating: /content/Audios/recordings/8_george_21.wav
#   inflating: /content/Audios/recordings/8_george_22.wav
#   inflating: /content/Audios/recordings/8_george_24.wav
#   inflating: /content/Audios/recordings/8_george_25.wav
#   inflating: /content/Audios/recordings/8_george_28.wav
#   inflating: /content/Audios/recordings/8_george_36.wav
#   inflating: /content/Audios/recordings/8_george_4.wav
#   inflating: /content/Audios/recordings/8_george_43.wav
#   inflating: /content/Audios/recordings/8_george_46.wav
#   inflating: /content/Audios/recordings/8_george_49.wav
#   inflating: /content/Audios/recordings/8_george_6.wav
#   inflating: /content/Audios/recordings/8_jackson_11.wav
#   inflating: /content/Audios/recordings/8_jackson_12.wav
#   inflating: /content/Audios/recordings/8_jackson_15.wav
#   inflating: /content/Audios/recordings/8_jackson_17.wav
#   inflating: /content/Audios/recordings/8_jackson_21.wav
#   inflating: /content/Audios/recordings/8_jackson_23.wav
#   inflating: /content/Audios/recordings/8_jackson_41.wav
#   inflating: /content/Audios/recordings/8_jackson_46.wav
# ...
#   inflating: /content/Audios/recordings/7_jackson_24.wav
#   inflating: /content/Audios/recordings/7_jackson_32.wav
#   inflating: /content/Audios/recordings/7_jackson_34.wav
#   inflating: /content/Audios/recordings/7_jackson_38.wav
#   inflating: /content/Audios/recordings/7_jackson_4.wav
#   inflating: /content/Audios/recordings/7_jackson_47.wav
#   inflating: /content/Audios/recordings/7_jackson_7.wav
#   inflating: /content/Audios/recordings/7_jackson_8.wav
#   inflating: /content/Audios/recordings/7_lucas_0.wav
#   inflating: /content/Audios/recordings/7_lucas_14.wav
#   inflating: /content/Audios/recordings/7_lucas_15.wav
#   inflating: /content/Audios/recordings/7_lucas_17.wav
#   inflating: /content/Audios/recordings/7_lucas_19.wav
#   inflating: /content/Audios/recordings/7_lucas_20.wav
#   inflating: /content/Audios/recordings/7_lucas_22.wav
#   inflating: /content/Audios/recordings/7_lucas_34.wav
#   inflating: /content/Audios/recordings/7_lucas_35.wav
#   inflating: /content/Audios/recordings/7_lucas_36.wav
#   inflating: /content/Audios/recordings/7_lucas_37.wav
#   inflating: /content/Audios/recordings/7_lucas_45.wav
#   inflating: /content/Audios/recordings/7_lucas_47.wav
#   inflating: /content/Audios/recordings/7_lucas_49.wav
#   inflating: /content/Audios/recordings/7_lucas_8.wav
#   inflating: /content/Audios/recordings/7_nicolas_1.wav
#   inflating: /content/Audios/recordings/7_nicolas_11.wav
#   inflating: /content/Audios/recordings/7_nicolas_15.wav
#   inflating: /content/Audios/recordings/7_nicolas_19.wav
#   inflating: /content/Audios/recordings/7_nicolas_2.wav
#   inflating: /content/Audios/recordings/7_nicolas_20.wav
#   inflating: /content/Audios/recordings/7_nicolas_21.wav
#   inflating: /content/Audios/recordings/7_nicolas_29.wav
#   inflating: /content/Audios/recordings/7_nicolas_3.wav
#   inflating: /content/Audios/recordings/7_nicolas_36.wav
#   inflating: /content/Audios/recordings/7_nicolas_40.wav
#   inflating: /content/Audios/recordings/7_nicolas_44.wav
#   inflating: /content/Audios/recordings/7_nicolas_48.wav
#   inflating: /content/Audios/recordings/7_nicolas_7.wav
#   inflating: /content/Audios/recordings/7_theo_10.wav
#   inflating: /content/Audios/recordings/7_theo_18.wav
#   inflating: /content/Audios/recordings/7_theo_2.wav
#   inflating: /content/Audios/recordings/7_theo_23.wav
#   inflating: /content/Audios/recordings/7_theo_26.wav
#   inflating: /content/Audios/recordings/7_theo_27.wav
#   inflating: /content/Audios/recordings/7_theo_31.wav
#   inflating: /content/Audios/recordings/7_theo_32.wav
#   inflating: /content/Audios/recordings/7_theo_33.wav
#   inflating: /content/Audios/recordings/7_theo_36.wav
#   inflating: /content/Audios/recordings/7_theo_37.wav
#   inflating: /content/Audios/recordings/7_theo_46.wav
#   inflating: /content/Audios/recordings/7_theo_47.wav
#   inflating: /content/Audios/recordings/7_theo_49.wav
#   inflating: /content/Audios/recordings/7_theo_6.wav
#   inflating: /content/Audios/recordings/7_yweweler_0.wav
#   inflating: /content/Audios/recordings/7_yweweler_17.wav
#   inflating: /content/Audios/recordings/7_yweweler_18.wav
#   inflating: /content/Audios/recordings/7_yweweler_19.wav
#   inflating: /content/Audios/recordings/7_yweweler_23.wav
#   inflating: /content/Audios/recordings/7_yweweler_28.wav
#   inflating: /content/Audios/recordings/7_yweweler_31.wav
#   inflating: /content/Audios/recordings/7_yweweler_39.wav
#   inflating: /content/Audios/recordings/7_yweweler_41.wav
#   inflating: /content/Audios/recordings/7_yweweler_43.wav
#   inflating: /content/Audios/recordings/7_yweweler_46.wav
#   inflating: /content/Audios/recordings/7_yweweler_47.wav
#   inflating: /content/Audios/recordings/7_yweweler_5.wav
#   inflating: /content/Audios/recordings/7_yweweler_6.wav
#   inflating: /content/Audios/recordings/7_yweweler_7.wav
#   inflating: /content/Audios/recordings/7_yweweler_8.wav
#   inflating: /content/Audios/recordings/8_george_1.wav
#   inflating: /content/Audios/recordings/8_george_12.wav
#   inflating: /content/Audios/recordings/8_george_13.wav
#   inflating: /content/Audios/recordings/8_george_17.wav
#   inflating: /content/Audios/recordings/8_george_19.wav
#   inflating: /content/Audios/recordings/8_george_20.wav
#   inflating: /content/Audios/recordings/8_george_27.wav
#   inflating: /content/Audios/recordings/8_george_32.wav
#   inflating: /content/Audios/recordings/8_george_33.wav
#   inflating: /content/Audios/recordings/8_george_34.wav
#   inflating: /content/Audios/recordings/8_george_37.wav
#   inflating: /content/Audios/recordings/8_george_38.wav
#   inflating: /content/Audios/recordings/8_george_42.wav
#   inflating: /content/Audios/recordings/8_george_44.wav
#   inflating: /content/Audios/recordings/8_george_48.wav
#   inflating: /content/Audios/recordings/8_george_5.wav
#   inflating: /content/Audios/recordings/8_george_7.wav
#   inflating: /content/Audios/recordings/8_jackson_0.wav
#   inflating: /content/Audios/recordings/8_jackson_19.wav
#   inflating: /content/Audios/recordings/8_jackson_2.wav
#   inflating: /content/Audios/recordings/8_jackson_20.wav
#   inflating: /content/Audios/recordings/8_jackson_22.wav
#   inflating: /content/Audios/recordings/8_jackson_25.wav
#   inflating: /content/Audios/recordings/8_jackson_26.wav
#   inflating: /content/Audios/recordings/8_jackson_27.wav
#   inflating: /content/Audios/recordings/8_jackson_28.wav
#   inflating: /content/Audios/recordings/8_jackson_29.wav
#   inflating: /content/Audios/recordings/8_jackson_31.wav
#   inflating: /content/Audios/recordings/8_jackson_32.wav
#   inflating: /content/Audios/recordings/8_jackson_36.wav
#   inflating: /content/Audios/recordings/8_jackson_38.wav
#   inflating: /content/Audios/recordings/8_jackson_39.wav
#   inflating: /content/Audios/recordings/8_jackson_4.wav
#   inflating: /content/Audios/recordings/8_jackson_48.wav
#   inflating: /content/Audios/recordings/8_jackson_7.wav
#   inflating: /content/Audios/recordings/8_jackson_9.wav
#   inflating: /content/Audios/recordings/8_lucas_1.wav
#   inflating: /content/Audios/recordings/8_lucas_11.wav
#   inflating: /content/Audios/recordings/8_lucas_13.wav
#   inflating: /content/Audios/recordings/8_lucas_14.wav
#   inflating: /content/Audios/recordings/8_lucas_16.wav
#   inflating: /content/Audios/recordings/8_lucas_2.wav
#   inflating: /content/Audios/recordings/8_lucas_21.wav
#   inflating: /content/Audios/recordings/8_lucas_22.wav
#   inflating: /content/Audios/recordings/8_lucas_23.wav
#   inflating: /content/Audios/recordings/8_lucas_28.wav
#   inflating: /content/Audios/recordings/8_lucas_36.wav
#   inflating: /content/Audios/recordings/8_lucas_37.wav
#   inflating: /content/Audios/recordings/8_lucas_38.wav
#   inflating: /content/Audios/recordings/8_lucas_39.wav
#   inflating: /content/Audios/recordings/8_lucas_45.wav
#   inflating: /content/Audios/recordings/8_lucas_6.wav
#   inflating: /content/Audios/recordings/8_lucas_9.wav
#   inflating: /content/Audios/recordings/8_nicolas_0.wav
#   inflating: /content/Audios/recordings/8_nicolas_14.wav
#   inflating: /content/Audios/recordings/8_nicolas_16.wav
#   inflating: /content/Audios/recordings/8_nicolas_18.wav
#   inflating: /content/Audios/recordings/8_nicolas_19.wav
#   inflating: /content/Audios/recordings/8_nicolas_2.wav
#   inflating: /content/Audios/recordings/8_nicolas_22.wav
#   inflating: /content/Audios/recordings/8_nicolas_23.wav
#   inflating: /content/Audios/recordings/8_nicolas_24.wav
#   inflating: /content/Audios/recordings/8_nicolas_26.wav
#   inflating: /content/Audios/recordings/8_nicolas_27.wav
#   inflating: /content/Audios/recordings/8_nicolas_28.wav
#   inflating: /content/Audios/recordings/8_nicolas_29.wav
#   inflating: /content/Audios/recordings/8_nicolas_34.wav
#   inflating: /content/Audios/recordings/8_nicolas_35.wav
#   inflating: /content/Audios/recordings/8_nicolas_41.wav
#   inflating: /content/Audios/recordings/8_nicolas_46.wav
#   inflating: /content/Audios/recordings/8_nicolas_7.wav
#   inflating: /content/Audios/recordings/8_nicolas_9.wav
#   inflating: /content/Audios/recordings/8_theo_0.wav
#   inflating: /content/Audios/recordings/8_theo_10.wav
#   inflating: /content/Audios/recordings/8_theo_14.wav
#   inflating: /content/Audios/recordings/8_theo_16.wav
#   inflating: /content/Audios/recordings/8_theo_18.wav
#   inflating: /content/Audios/recordings/8_theo_28.wav
#   inflating: /content/Audios/recordings/8_theo_30.wav
#   inflating: /content/Audios/recordings/8_theo_34.wav
#   inflating: /content/Audios/recordings/8_theo_39.wav
#   inflating: /content/Audios/recordings/8_theo_4.wav
#   inflating: /content/Audios/recordings/8_theo_40.wav
#   inflating: /content/Audios/recordings/8_theo_42.wav
#   inflating: /content/Audios/recordings/8_theo_43.wav
#   inflating: /content/Audios/recordings/8_theo_47.wav
#   inflating: /content/Audios/recordings/8_yweweler_1.wav
#   inflating: /content/Audios/recordings/8_yweweler_12.wav
#   inflating: /content/Audios/recordings/8_yweweler_15.wav
#   inflating: /content/Audios/recordings/8_yweweler_18.wav
#   inflating: /content/Audios/recordings/8_yweweler_2.wav
#   inflating: /content/Audios/recordings/8_yweweler_21.wav
#   inflating: /content/Audios/recordings/8_yweweler_22.wav
#   inflating: /content/Audios/recordings/8_yweweler_25.wav
#   inflating: /content/Audios/recordings/8_yweweler_30.wav
#   inflating: /content/Audios/recordings/8_yweweler_33.wav
#   inflating: /content/Audios/recordings/8_yweweler_35.wav
#   inflating: /content/Audios/recordings/8_yweweler_38.wav
#   inflating: /content/Audios/recordings/8_yweweler_47.wav
#   inflating: /content/Audios/recordings/8_yweweler_49.wav
#   inflating: /content/Audios/recordings/8_yweweler_6.wav
#   inflating: /content/Audios/recordings/9_george_10.wav
#   inflating: /content/Audios/recordings/9_george_15.wav
#   inflating: /content/Audios/recordings/9_george_17.wav
#   inflating: /content/Audios/recordings/9_george_18.wav
#   inflating: /content/Audios/recordings/9_george_20.wav
#   inflating: /content/Audios/recordings/9_george_22.wav
#   inflating: /content/Audios/recordings/9_george_26.wav
#   inflating: /content/Audios/recordings/9_george_30.wav
#   inflating: /content/Audios/recordings/9_george_32.wav
#   inflating: /content/Audios/recordings/9_george_34.wav
#   inflating: /content/Audios/recordings/9_george_38.wav
#   inflating: /content/Audios/recordings/9_george_39.wav
#   inflating: /content/Audios/recordings/9_george_40.wav
#   inflating: /content/Audios/recordings/9_george_45.wav
#   inflating: /content/Audios/recordings/9_george_46.wav
#   inflating: /content/Audios/recordings/9_george_8.wav
#   inflating: /content/Audios/recordings/9_george_9.wav
#   inflating: /content/Audios/recordings/9_jackson_10.wav
#   inflating: /content/Audios/recordings/9_jackson_14.wav
#   inflating: /content/Audios/recordings/9_jackson_2.wav
#   inflating: /content/Audios/recordings/9_jackson_20.wav
#   inflating: /content/Audios/recordings/9_jackson_21.wav
#   inflating: /content/Audios/recordings/9_jackson_26.wav
#   inflating: /content/Audios/recordings/9_jackson_28.wav
#   inflating: /content/Audios/recordings/9_jackson_29.wav
#   inflating: /content/Audios/recordings/9_jackson_3.wav
#   inflating: /content/Audios/recordings/9_jackson_33.wav
#   inflating: /content/Audios/recordings/9_jackson_42.wav
#   inflating: /content/Audios/recordings/9_jackson_47.wav
#   inflating: /content/Audios/recordings/9_jackson_7.wav
#   inflating: /content/Audios/recordings/9_lucas_12.wav
#   inflating: /content/Audios/recordings/9_lucas_14.wav
#   inflating: /content/Audios/recordings/9_lucas_15.wav
#   inflating: /content/Audios/recordings/9_lucas_17.wav
#   inflating: /content/Audios/recordings/9_lucas_18.wav
#   inflating: /content/Audios/recordings/9_lucas_22.wav
#   inflating: /content/Audios/recordings/9_lucas_23.wav
#   inflating: /content/Audios/recordings/9_lucas_25.wav
#   inflating: /content/Audios/recordings/9_lucas_26.wav
#   inflating: /content/Audios/recordings/9_lucas_29.wav
#   inflating: /content/Audios/recordings/9_lucas_30.wav
#   inflating: /content/Audios/recordings/9_lucas_31.wav
#   inflating: /content/Audios/recordings/9_lucas_33.wav
#   inflating: /content/Audios/recordings/9_lucas_34.wav
#   inflating: /content/Audios/recordings/9_lucas_35.wav
#   inflating: /content/Audios/recordings/9_lucas_38.wav
#   inflating: /content/Audios/recordings/9_lucas_4.wav
#   inflating: /content/Audios/recordings/9_lucas_43.wav
#   inflating: /content/Audios/recordings/9_lucas_45.wav
#   inflating: /content/Audios/recordings/9_lucas_46.wav
#   inflating: /content/Audios/recordings/9_lucas_47.wav
#   inflating: /content/Audios/recordings/9_lucas_5.wav
#   inflating: /content/Audios/recordings/9_lucas_6.wav
#   inflating: /content/Audios/recordings/9_nicolas_13.wav
#   inflating: /content/Audios/recordings/9_nicolas_16.wav
#   inflating: /content/Audios/recordings/9_nicolas_18.wav
#   inflating: /content/Audios/recordings/9_nicolas_19.wav
#   inflating: /content/Audios/recordings/9_nicolas_2.wav
#   inflating: /content/Audios/recordings/9_nicolas_24.wav
#   inflating: /content/Audios/recordings/9_nicolas_28.wav
#   inflating: /content/Audios/recordings/9_nicolas_30.wav
#   inflating: /content/Audios/recordings/9_nicolas_34.wav
#   inflating: /content/Audios/recordings/9_nicolas_35.wav
#   inflating: /content/Audios/recordings/9_nicolas_39.wav
#   inflating: /content/Audios/recordings/9_nicolas_40.wav
#   inflating: /content/Audios/recordings/9_nicolas_43.wav
#   inflating: /content/Audios/recordings/9_nicolas_46.wav
#   inflating: /content/Audios/recordings/9_nicolas_48.wav
#   inflating: /content/Audios/recordings/9_nicolas_5.wav
#   inflating: /content/Audios/recordings/9_nicolas_9.wav
#   inflating: /content/Audios/recordings/9_theo_0.wav
#   inflating: /content/Audios/recordings/9_theo_1.wav
#   inflating: /content/Audios/recordings/9_theo_12.wav
#   inflating: /content/Audios/recordings/9_theo_16.wav
#   inflating: /content/Audios/recordings/9_theo_19.wav
#   inflating: /content/Audios/recordings/9_theo_20.wav
#   inflating: /content/Audios/recordings/9_theo_22.wav
#   inflating: /content/Audios/recordings/9_theo_29.wav
#   inflating: /content/Audios/recordings/9_theo_3.wav
#   inflating: /content/Audios/recordings/9_theo_32.wav
#   inflating: /content/Audios/recordings/9_theo_35.wav
#   inflating: /content/Audios/recordings/9_theo_37.wav
#   inflating: /content/Audios/recordings/9_theo_4.wav
#   inflating: /content/Audios/recordings/9_theo_41.wav
#   inflating: /content/Audios/recordings/9_theo_46.wav
#   inflating: /content/Audios/recordings/9_theo_48.wav
#   inflating: /content/Audios/recordings/9_theo_6.wav
#   inflating: /content/Audios/recordings/9_theo_8.wav
#   inflating: /content/Audios/recordings/9_yweweler_1.wav
#   inflating: /content/Audios/recordings/9_yweweler_10.wav
#   inflating: /content/Audios/recordings/9_yweweler_11.wav
#   inflating: /content/Audios/recordings/9_yweweler_17.wav
#   inflating: /content/Audios/recordings/9_yweweler_21.wav
#   inflating: /content/Audios/recordings/9_yweweler_26.wav
#   inflating: /content/Audios/recordings/9_yweweler_27.wav
#   inflating: /content/Audios/recordings/9_yweweler_31.wav
#   inflating: /content/Audios/recordings/9_yweweler_34.wav
#   inflating: /content/Audios/recordings/9_yweweler_35.wav
#   inflating: /content/Audios/recordings/9_yweweler_36.wav
#   inflating: /content/Audios/recordings/9_yweweler_37.wav
#   inflating: /content/Audios/recordings/9_yweweler_38.wav
#   inflating: /content/Audios/recordings/9_yweweler_44.wav
#   inflating: /content/Audios/recordings/9_yweweler_47.wav
#   inflating: /content/Audios/recordings/9_yweweler_48.wav
#   inflating: /content/Audios/recordings/9_yweweler_5.wav
#   inflating: /content/Audios/recordings/9_yweweler_6.wav
#   inflating: /content/Audios/recordings/9_yweweler_8.wav

# %%
"""
1- load a file
2- pad the signal (if necessary)
3- extracting log spectrogram from signal
4- normalise spectrogram
5- save the normalised spectrogram

PreprocessingPipeline
"""


class Loader:
    """Loader is responsible for loading an audio file."""

    def __init__(self, sample_rate, duration, mono):
        self.sample_rate = sample_rate
        self.duration = duration
        self.mono = mono

    def load(self, file_path):
        signal = librosa.load(file_path,
                              sr=self.sample_rate,
                              duration=self.duration,
                              mono=self.mono)[0]
        return signal


class Padder:
    """Padder is responsible to apply padding to an array."""

    def __init__(self, mode="constant"):
        self.mode = mode

    def left_pad(self, array, num_missing_items):
        padded_array = np.pad(array,
                              (num_missing_items, 0),
                              mode=self.mode)
        return padded_array

    def right_pad(self, array, num_missing_items):
        padded_array = np.pad(array,
                              (0, num_missing_items),
                              mode=self.mode)
        return padded_array


class LogSpectrogramExtractor:
    """LogSpectrogramExtractor extracts log spectrograms (in dB) from a
    time-series signal.
    """

    def __init__(self, frame_size, hop_length):
        self.frame_size = frame_size
        self.hop_length = hop_length

    def extract(self, signal):
        stft = librosa.stft(signal,
                            n_fft=self.frame_size,
                            hop_length=self.hop_length)[:-1]
        spectrogram = np.abs(stft)
        log_spectrogram = librosa.amplitude_to_db(spectrogram)
        return log_spectrogram


class MinMaxNormaliser:
    """MinMaxNormaliser applies min max normalisation to an array."""

    def __init__(self, min_val, max_val):
        self.min = min_val
        self.max = max_val

    def normalise(self, array):
        norm_array = (array - array.min()) / (array.max() - array.min())
        norm_array = norm_array * (self.max - self.min) + self.min
        return norm_array

    def denormalise(self, norm_array, original_min, original_max):
        array = (norm_array - self.min) / (self.max - self.min)
        array = array * (original_max - original_min) + original_min
        return array


class Saver:
    """saver is responsible to save features, and the min max values."""

    def __init__(self, min_max_values_save_dir): #feature_save_dir, min_max_values_save_dir):
        #self.feature_save_dir = feature_save_dir
        self.min_max_values_save_dir = min_max_values_save_dir

    def save_feature(self, feature, file_path):
        save_path = self._generate_save_path(file_path)
        np.save(save_path, feature)

    def save_min_max_values(self, min_max_values):
        save_path = os.path.join(self.min_max_values_save_dir,"min_max_values.pkl")
        self._save(min_max_values, save_path)

    @staticmethod
    def _save(data, save_path):
        with open(save_path, "wb") as f:
            pickle.dump(data, f)

    def _generate_save_path(self, file_path):
        file_name = os.path.split(file_path)[1]
        save_path = os.path.join(self.feature_save_dir, file_name + ".npy")
        return save_path


class PreprocessingPipeline:
    """PreprocessingPipeline processes audio files in a directory, applying
    the following steps to each file:
        1- load a file
        2- pad the signal (if necessary)
        3- extracting log spectrogram from signal
        4- normalise spectrogram
        5- save the normalised spectrogram

    Storing the min max values for all the log spectrograms.
    """

    def __init__(self):
        self.padder = None
        self.extractor = None
        self.normaliser = None
        self.saver = None
        self.min_max_values = {}
        self._loader = None
        self._num_expected_samples = None

    @property
    def loader(self):
        return self._loader

    @loader.setter
    def loader(self, loader):
        self._loader = loader
        self._num_expected_samples = int(loader.sample_rate * loader.duration)

    def process(self, audio_files_dir):
        for root, _, files in os.walk(audio_files_dir):
            for filep in files:
                file_path = os.path.join(root, filep)
                self._process_file(file_path, filep)
                print(f"Processed file {filep}")
        self.saver.save_min_max_values(self.min_max_values)

    def _process_file(self, file_path, filep):
        signal = self.loader.load(file_path)
        if self._is_padding_necessary(signal):
            signal = self._apply_padding(signal)
        feature = self.extractor.extract(signal)
        #norm_feature = self.normaliser.normalise(feature)
        #save_path = self.saver.save_feature(norm_feature, file_path)
        self._store_min_max_value(filep, feature.min(), feature.max())

    def _is_padding_necessary(self, signal):
        if len(signal) < self._num_expected_samples:
            return True
        return False

    def _apply_padding(self, signal):
        num_missing_samples = self._num_expected_samples - len(signal)
        padded_signal = self.padder.right_pad(signal, num_missing_samples)
        return padded_signal

    def _store_min_max_value(self, filep, min_val, max_val):
      save_path = '/content/drive/MyDrive/Data_AudioGen/fsdd/spectrograms/' + filep + '.npy'
      self.min_max_values[save_path] = {
          "min": min_val,
          "max": max_val
      }

if __name__ == "__main__":
    FRAME_SIZE = 512
    HOP_LENGTH = 256
    DURATION = 0.74  # in seconds
    SAMPLE_RATE = 22050
    MONO = True

    MIN_MAX_VALUES_SAVE_DIR = "/content/drive/MyDrive/Data_AudioGen/fsdd"
    #SPECTROGRAMS_SAVE_DIR = "/content/drive/MyDrive/Data_AudioGen/fsdd/spectrograms/"
    FILES_DIR = "/content/Audios"

    # instantiate all objects
    loader = Loader(SAMPLE_RATE, DURATION, MONO)
    padder = Padder()
    log_spectrogram_extractor = LogSpectrogramExtractor(FRAME_SIZE, HOP_LENGTH)
    min_max_normaliser = MinMaxNormaliser(0, 1)
    saver = Saver(MIN_MAX_VALUES_SAVE_DIR)#SPECTROGRAMS_SAVE_DIR, MIN_MAX_VALUES_SAVE_DIR)

    preprocessing_pipeline = PreprocessingPipeline()
    preprocessing_pipeline.loader = loader
    preprocessing_pipeline.padder = padder
    preprocessing_pipeline.extractor = log_spectrogram_extractor
    preprocessing_pipeline.normaliser = min_max_normaliser
    preprocessing_pipeline.saver = saver

    preprocessing_pipeline.process(FILES_DIR)
# Out:
# Processed file 3_jackson_30.wav
# Processed file 4_theo_37.wav
# Processed file 1_lucas_14.wav
# Processed file 5_nicolas_8.wav
# Processed file 5_theo_32.wav
# Processed file 5_george_28.wav
# Processed file 6_theo_31.wav
# Processed file 8_george_9.wav
# Processed file 6_yweweler_12.wav
# Processed file 4_theo_33.wav
# Processed file 1_george_48.wav
# Processed file 2_theo_19.wav
# Processed file 1_nicolas_1.wav
# Processed file 9_jackson_14.wav
# Processed file 4_nicolas_26.wav
# Processed file 1_theo_1.wav
# Processed file 7_george_4.wav
# Processed file 6_nicolas_14.wav
# Processed file 1_lucas_30.wav
# Processed file 0_jackson_44.wav
# Processed file 4_lucas_0.wav
# Processed file 9_jackson_6.wav
# Processed file 5_nicolas_44.wav
# Processed file 5_lucas_2.wav
# Processed file 6_jackson_47.wav
# Processed file 7_george_9.wav
# Processed file 0_theo_13.wav
# Processed file 2_yweweler_0.wav
# Processed file 8_lucas_27.wav
# Processed file 0_yweweler_7.wav
# Processed file 9_theo_18.wav
# Processed file 7_jackson_39.wav
# Processed file 1_yweweler_41.wav
# Processed file 5_george_11.wav
# Processed file 6_theo_5.wav
# Processed file 8_yweweler_9.wav
# Processed file 7_jackson_20.wav
# Processed file 8_lucas_36.wav
# Processed file 1_yweweler_49.wav
# Processed file 4_theo_26.wav
# Processed file 8_lucas_3.wav
# Processed file 1_george_13.wav
# Processed file 0_theo_32.wav
# Processed file 0_george_5.wav
# Processed file 6_theo_34.wav
# Processed file 1_theo_47.wav
# Processed file 4_lucas_40.wav
# Processed file 3_yweweler_34.wav
# Processed file 6_yweweler_34.wav
# Processed file 6_nicolas_10.wav
# Processed file 4_lucas_20.wav
# Processed file 7_lucas_4.wav
# Processed file 2_yweweler_24.wav
# Processed file 0_theo_45.wav
# Processed file 7_lucas_16.wav
# Processed file 2_nicolas_32.wav
# Processed file 5_george_3.wav
# Processed file 1_nicolas_24.wav
# Processed file 8_yweweler_20.wav
# Processed file 6_lucas_5.wav
# Processed file 9_george_49.wav
# Processed file 4_nicolas_3.wav
# Processed file 6_nicolas_41.wav
# Processed file 5_theo_29.wav
# Processed file 1_theo_10.wav
# Processed file 9_theo_45.wav
# Processed file 1_jackson_46.wav
# Processed file 5_nicolas_48.wav
# Processed file 7_yweweler_31.wav
# Processed file 2_nicolas_24.wav
# Processed file 5_jackson_11.wav
# Processed file 4_jackson_6.wav
# Processed file 6_yweweler_41.wav
# Processed file 2_theo_36.wav
# Processed file 8_jackson_24.wav
# Processed file 3_nicolas_41.wav
# Processed file 5_nicolas_9.wav
# Processed file 7_jackson_34.wav
# Processed file 9_george_24.wav
# Processed file 3_george_21.wav
# Processed file 9_george_42.wav
# Processed file 8_george_34.wav
# Processed file 8_lucas_0.wav
# Processed file 2_yweweler_34.wav
# Processed file 0_nicolas_48.wav
# Processed file 0_theo_16.wav
# Processed file 8_george_47.wav
# Processed file 3_yweweler_4.wav
# Processed file 0_yweweler_13.wav
# Processed file 6_jackson_15.wav
# Processed file 5_george_24.wav
# Processed file 4_yweweler_29.wav
# Processed file 2_nicolas_5.wav
# Processed file 3_yweweler_9.wav
# Processed file 8_jackson_27.wav
# Processed file 5_yweweler_14.wav
# Processed file 0_george_40.wav
# Processed file 0_theo_36.wav
# Processed file 0_theo_22.wav
# Processed file 7_lucas_24.wav
# Processed file 9_george_47.wav
# Processed file 6_theo_23.wav
# Processed file 2_lucas_36.wav
# Processed file 0_nicolas_49.wav
# Processed file 9_theo_11.wav
# Processed file 7_nicolas_47.wav
# Processed file 9_george_26.wav
# Processed file 1_jackson_37.wav
# Processed file 2_jackson_2.wav
# Processed file 8_jackson_23.wav
# Processed file 4_george_23.wav
# Processed file 7_lucas_35.wav
# Processed file 2_nicolas_23.wav
# Processed file 3_lucas_22.wav
# Processed file 0_george_39.wav
# Processed file 4_nicolas_27.wav
# Processed file 0_george_22.wav
# Processed file 6_jackson_26.wav
# Processed file 7_yweweler_47.wav
# Processed file 9_lucas_25.wav
# Processed file 9_nicolas_24.wav
# Processed file 7_nicolas_9.wav
# Processed file 1_jackson_49.wav
# Processed file 2_lucas_9.wav
# Processed file 9_lucas_28.wav
# Processed file 7_george_14.wav
# Processed file 2_nicolas_33.wav
# Processed file 2_george_10.wav
# Processed file 1_jackson_42.wav
# Processed file 1_george_34.wav
# Processed file 9_yweweler_43.wav
# Processed file 3_lucas_10.wav
# Processed file 0_nicolas_25.wav
# Processed file 0_yweweler_23.wav
# Processed file 2_jackson_29.wav
# Processed file 0_yweweler_34.wav
# Processed file 3_george_15.wav
# Processed file 9_nicolas_41.wav
# Processed file 1_yweweler_2.wav
# Processed file 4_jackson_10.wav
# Processed file 0_theo_25.wav
# Processed file 7_lucas_11.wav
# Processed file 4_yweweler_23.wav
# Processed file 8_yweweler_47.wav
# Processed file 4_theo_43.wav
# Processed file 6_nicolas_18.wav
# Processed file 6_lucas_13.wav
# Processed file 1_george_49.wav
# Processed file 5_george_49.wav
# Processed file 4_theo_16.wav
# Processed file 2_jackson_35.wav
# Processed file 7_theo_20.wav
# Processed file 2_theo_33.wav
# Processed file 2_nicolas_20.wav
# Processed file 8_nicolas_46.wav
# Processed file 1_jackson_13.wav
# Processed file 2_george_44.wav
# Processed file 1_lucas_44.wav
# Processed file 5_theo_2.wav
# Processed file 7_george_36.wav
# Processed file 0_lucas_36.wav
# Processed file 0_lucas_25.wav
# Processed file 1_nicolas_29.wav
# Processed file 6_george_24.wav
# Processed file 3_jackson_19.wav
# Processed file 5_jackson_46.wav
# Processed file 9_nicolas_26.wav
# Processed file 1_lucas_35.wav
# Processed file 0_yweweler_10.wav
# Processed file 7_yweweler_38.wav
# Processed file 3_theo_5.wav
# Processed file 8_yweweler_0.wav
# Processed file 2_jackson_12.wav
# Processed file 6_lucas_35.wav
# Processed file 9_george_0.wav
# Processed file 5_theo_31.wav
# Processed file 7_jackson_11.wav
# Processed file 1_lucas_16.wav
# Processed file 0_jackson_8.wav
# Processed file 2_yweweler_47.wav
# Processed file 2_george_28.wav
# Processed file 6_lucas_23.wav
# Processed file 2_nicolas_12.wav
# Processed file 5_yweweler_12.wav
# Processed file 1_jackson_1.wav
# Processed file 6_george_49.wav
# Processed file 3_lucas_27.wav
# Processed file 7_lucas_42.wav
# Processed file 7_yweweler_29.wav
# Processed file 3_lucas_46.wav
# Processed file 2_nicolas_31.wav
# Processed file 9_theo_38.wav
# Processed file 2_jackson_43.wav
# Processed file 3_theo_19.wav
# Processed file 3_jackson_6.wav
# Processed file 9_yweweler_41.wav
# Processed file 7_jackson_3.wav
# Processed file 2_yweweler_17.wav
# Processed file 1_yweweler_24.wav
# Processed file 7_nicolas_30.wav
# Processed file 6_george_36.wav
# Processed file 1_jackson_19.wav
# Processed file 1_george_16.wav
# Processed file 2_nicolas_29.wav
# Processed file 7_nicolas_45.wav
# Processed file 1_george_47.wav
# Processed file 3_lucas_24.wav
# Processed file 7_theo_46.wav
# Processed file 0_lucas_13.wav
# Processed file 6_yweweler_43.wav
# Processed file 2_yweweler_22.wav
# Processed file 9_george_31.wav
# Processed file 6_jackson_12.wav
# Processed file 2_nicolas_15.wav
# Processed file 0_george_19.wav
# Processed file 4_lucas_18.wav
# Processed file 7_jackson_44.wav
# Processed file 6_george_39.wav
# Processed file 4_jackson_46.wav
# Processed file 7_yweweler_45.wav
# Processed file 3_george_19.wav
# Processed file 5_lucas_29.wav
# Processed file 0_nicolas_31.wav
# Processed file 7_george_22.wav
# Processed file 1_lucas_33.wav
# Processed file 5_lucas_48.wav
# Processed file 3_yweweler_35.wav
# Processed file 9_yweweler_10.wav
# Processed file 3_jackson_15.wav
# Processed file 0_jackson_21.wav
# Processed file 1_yweweler_26.wav
# Processed file 7_lucas_22.wav
# Processed file 1_theo_26.wav
# Processed file 0_lucas_11.wav
# Processed file 5_lucas_47.wav
# Processed file 7_jackson_8.wav
# Processed file 5_yweweler_8.wav
# Processed file 0_theo_23.wav
# Processed file 4_theo_45.wav
# Processed file 9_theo_26.wav
# Processed file 4_yweweler_49.wav
# Processed file 9_nicolas_30.wav
# Processed file 5_yweweler_49.wav
# Processed file 0_yweweler_27.wav
# Processed file 7_yweweler_13.wav
# Processed file 0_george_3.wav
# Processed file 6_theo_6.wav
# Processed file 1_nicolas_16.wav
# Processed file 9_lucas_29.wav
# Processed file 1_nicolas_35.wav
# Processed file 0_yweweler_17.wav
# Processed file 8_theo_9.wav
# Processed file 0_theo_48.wav
# Processed file 4_jackson_33.wav
# Processed file 0_jackson_6.wav
# Processed file 7_yweweler_17.wav
# Processed file 9_theo_37.wav
# Processed file 9_nicolas_25.wav
# Processed file 5_theo_1.wav
# Processed file 3_jackson_48.wav
# Processed file 5_lucas_9.wav
# Processed file 8_yweweler_10.wav
# Processed file 7_lucas_41.wav
# Processed file 1_lucas_10.wav
# Processed file 3_george_6.wav
# Processed file 5_jackson_8.wav
# Processed file 7_jackson_19.wav
# Processed file 8_george_46.wav
# Processed file 8_george_32.wav
# Processed file 6_yweweler_31.wav
# Processed file 3_george_49.wav
# Processed file 7_george_19.wav
# Processed file 3_jackson_9.wav
# Processed file 9_theo_1.wav
# Processed file 7_george_12.wav
# Processed file 0_george_11.wav
# Processed file 5_lucas_23.wav
# Processed file 3_nicolas_22.wav
# Processed file 1_nicolas_45.wav
# Processed file 4_george_18.wav
# Processed file 4_george_29.wav
# Processed file 5_nicolas_39.wav
# Processed file 9_yweweler_35.wav
# Processed file 5_theo_45.wav
# Processed file 1_nicolas_21.wav
# Processed file 2_lucas_33.wav
# Processed file 4_jackson_26.wav
# Processed file 8_lucas_43.wav
# Processed file 2_theo_26.wav
# Processed file 4_jackson_16.wav
# Processed file 9_nicolas_21.wav
# Processed file 7_george_11.wav
# Processed file 1_theo_35.wav
# Processed file 2_theo_31.wav
# Processed file 3_theo_32.wav
# Processed file 6_george_29.wav
# Processed file 4_theo_24.wav
# Processed file 3_nicolas_45.wav
# Processed file 8_nicolas_25.wav
# Processed file 3_lucas_12.wav
# Processed file 8_theo_22.wav
# Processed file 5_jackson_45.wav
# Processed file 1_yweweler_19.wav
# Processed file 8_yweweler_13.wav
# Processed file 0_yweweler_12.wav
# Processed file 4_george_49.wav
# Processed file 0_lucas_16.wav
# Processed file 3_nicolas_36.wav
# Processed file 3_yweweler_29.wav
# Processed file 2_yweweler_44.wav
# Processed file 7_theo_43.wav
# Processed file 9_lucas_2.wav
# Processed file 7_nicolas_37.wav
# Processed file 5_theo_39.wav
# Processed file 0_george_33.wav
# Processed file 8_yweweler_34.wav
# Processed file 5_lucas_13.wav
# Processed file 4_theo_9.wav
# Processed file 4_lucas_31.wav
# Processed file 7_theo_49.wav
# Processed file 5_nicolas_35.wav
# Processed file 0_george_8.wav
# Processed file 1_lucas_28.wav
# Processed file 2_nicolas_25.wav
# Processed file 5_lucas_21.wav
# Processed file 3_theo_29.wav
# Processed file 0_lucas_44.wav
# Processed file 4_george_44.wav
# Processed file 4_nicolas_37.wav
# Processed file 5_nicolas_23.wav
# Processed file 9_lucas_18.wav
# Processed file 3_theo_41.wav
# Processed file 8_theo_29.wav
# Processed file 8_yweweler_32.wav
# Processed file 1_lucas_23.wav
# Processed file 7_jackson_42.wav
# Processed file 5_nicolas_37.wav
# Processed file 9_theo_43.wav
# Processed file 6_jackson_36.wav
# Processed file 5_george_21.wav
# Processed file 5_george_20.wav
# Processed file 6_jackson_29.wav
# Processed file 6_george_47.wav
# Processed file 7_lucas_1.wav
# Processed file 3_theo_0.wav
# Processed file 4_theo_22.wav
# Processed file 3_yweweler_7.wav
# Processed file 8_lucas_38.wav
# Processed file 9_yweweler_46.wav
# Processed file 2_lucas_5.wav
# Processed file 5_george_29.wav
# Processed file 1_theo_44.wav
# Processed file 9_theo_31.wav
# Processed file 6_lucas_22.wav
# Processed file 9_yweweler_16.wav
# Processed file 4_george_7.wav
# Processed file 5_jackson_33.wav
# Processed file 5_theo_12.wav
# Processed file 7_nicolas_20.wav
# Processed file 8_lucas_45.wav
# Processed file 9_lucas_41.wav
# Processed file 8_jackson_18.wav
# Processed file 8_george_48.wav
# Processed file 5_lucas_36.wav
# Processed file 6_george_44.wav
# Processed file 3_jackson_46.wav
# Processed file 6_nicolas_12.wav
# Processed file 3_nicolas_40.wav
# Processed file 4_yweweler_1.wav
# Processed file 9_yweweler_14.wav
# Processed file 2_theo_3.wav
# Processed file 5_lucas_7.wav
# Processed file 4_jackson_4.wav
# Processed file 6_theo_35.wav
# Processed file 6_george_11.wav
# Processed file 5_george_46.wav
# Processed file 2_jackson_6.wav
# Processed file 4_yweweler_47.wav
# Processed file 4_yweweler_41.wav
# Processed file 6_nicolas_37.wav
# Processed file 9_theo_33.wav
# Processed file 6_lucas_19.wav
# Processed file 6_theo_37.wav
# Processed file 0_lucas_42.wav
# Processed file 5_lucas_16.wav
# Processed file 5_george_42.wav
# Processed file 2_nicolas_8.wav
# Processed file 2_yweweler_39.wav
# Processed file 6_yweweler_44.wav
# Processed file 2_yweweler_46.wav
# Processed file 9_nicolas_12.wav
# Processed file 9_nicolas_37.wav
# Processed file 9_yweweler_5.wav
# Processed file 4_george_45.wav
# Processed file 6_yweweler_37.wav
# Processed file 3_nicolas_12.wav
# Processed file 9_jackson_7.wav
# Processed file 6_theo_4.wav
# Processed file 6_lucas_32.wav
# Processed file 3_nicolas_14.wav
# Processed file 7_nicolas_25.wav
# Processed file 8_george_11.wav
# Processed file 1_theo_38.wav
# Processed file 0_theo_34.wav
# Processed file 9_nicolas_14.wav
# Processed file 2_lucas_11.wav
# Processed file 9_jackson_1.wav
# Processed file 7_jackson_17.wav
# Processed file 8_theo_6.wav
# Processed file 4_george_19.wav
# Processed file 8_jackson_38.wav
# Processed file 9_jackson_44.wav
# Processed file 8_jackson_47.wav
# Processed file 3_lucas_35.wav
# Processed file 3_theo_30.wav
# Processed file 2_jackson_8.wav
# Processed file 7_jackson_1.wav
# Processed file 6_nicolas_27.wav
# Processed file 0_george_10.wav
# Processed file 5_theo_43.wav
# Processed file 8_theo_1.wav
# Processed file 3_yweweler_27.wav
# Processed file 8_yweweler_4.wav
# Processed file 6_nicolas_11.wav
# Processed file 0_nicolas_35.wav
# Processed file 0_nicolas_22.wav
# Processed file 4_george_41.wav
# Processed file 8_nicolas_6.wav
# Processed file 8_nicolas_4.wav
# Processed file 0_theo_19.wav
# Processed file 7_yweweler_24.wav
# Processed file 8_nicolas_24.wav
# Processed file 0_lucas_21.wav
# Processed file 7_jackson_22.wav
# Processed file 9_nicolas_18.wav
# Processed file 3_yweweler_37.wav
# Processed file 9_jackson_47.wav
# Processed file 9_lucas_8.wav
# Processed file 0_yweweler_37.wav
# Processed file 5_lucas_45.wav
# Processed file 1_yweweler_22.wav
# Processed file 0_jackson_4.wav
# Processed file 2_nicolas_14.wav
# Processed file 5_nicolas_28.wav
# Processed file 0_george_12.wav
# Processed file 5_jackson_6.wav
# Processed file 6_yweweler_27.wav
# Processed file 8_nicolas_36.wav
# Processed file 8_theo_45.wav
# Processed file 5_jackson_5.wav
# Processed file 0_nicolas_44.wav
# Processed file 6_lucas_11.wav
# Processed file 4_nicolas_18.wav
# Processed file 2_lucas_40.wav
# Processed file 5_yweweler_20.wav
# Processed file 4_george_31.wav
# Processed file 2_theo_49.wav
# Processed file 4_yweweler_10.wav
# Processed file 8_nicolas_15.wav
# Processed file 2_lucas_43.wav
# Processed file 1_george_25.wav
# Processed file 5_jackson_31.wav
# Processed file 7_yweweler_5.wav
# Processed file 4_lucas_1.wav
# Processed file 8_yweweler_14.wav
# Processed file 0_george_14.wav
# Processed file 8_george_16.wav
# Processed file 5_theo_17.wav
# Processed file 4_george_21.wav
# Processed file 0_george_30.wav
# Processed file 3_yweweler_46.wav
# Processed file 2_nicolas_0.wav
# Processed file 5_nicolas_14.wav
# Processed file 1_lucas_46.wav
# Processed file 4_yweweler_6.wav
# Processed file 8_nicolas_3.wav
# Processed file 3_nicolas_28.wav
# Processed file 4_nicolas_2.wav
# Processed file 8_nicolas_43.wav
# Processed file 4_lucas_13.wav
# Processed file 4_jackson_37.wav
# Processed file 3_lucas_41.wav
# Processed file 5_theo_3.wav
# Processed file 9_lucas_13.wav
# Processed file 8_george_7.wav
# Processed file 8_jackson_48.wav
# Processed file 4_jackson_8.wav
# Processed file 4_nicolas_45.wav
# Processed file 8_george_36.wav
# Processed file 4_yweweler_20.wav
# Processed file 4_jackson_1.wav
# Processed file 2_lucas_7.wav
# Processed file 3_jackson_38.wav
# Processed file 0_nicolas_47.wav
# Processed file 4_jackson_22.wav
# Processed file 4_jackson_13.wav
# Processed file 8_nicolas_17.wav
# Processed file 0_jackson_48.wav
# Processed file 0_yweweler_49.wav
# Processed file 0_yweweler_48.wav
# Processed file 2_yweweler_16.wav
# Processed file 3_nicolas_24.wav
# Processed file 6_lucas_26.wav
# Processed file 6_george_31.wav
# Processed file 8_george_3.wav
# Processed file 1_nicolas_3.wav
# Processed file 8_lucas_15.wav
# Processed file 4_nicolas_1.wav
# Processed file 8_yweweler_17.wav
# Processed file 9_yweweler_34.wav
# Processed file 7_george_28.wav
# Processed file 0_nicolas_26.wav
# Processed file 5_yweweler_34.wav
# Processed file 0_yweweler_5.wav
# Processed file 9_jackson_42.wav
# Processed file 3_theo_17.wav
# Processed file 6_lucas_2.wav
# Processed file 9_nicolas_35.wav
# Processed file 5_yweweler_45.wav
# Processed file 1_george_6.wav
# Processed file 0_yweweler_38.wav
# Processed file 5_lucas_31.wav
# Processed file 4_nicolas_17.wav
# Processed file 0_yweweler_19.wav
# Processed file 4_george_9.wav
# Processed file 6_yweweler_4.wav
# Processed file 2_nicolas_7.wav
# Processed file 2_yweweler_12.wav
# Processed file 4_yweweler_43.wav
# Processed file 9_jackson_46.wav
# Processed file 8_george_14.wav
# Processed file 6_theo_39.wav
# Processed file 0_yweweler_8.wav
# Processed file 3_nicolas_35.wav
# Processed file 3_jackson_10.wav
# Processed file 2_george_26.wav
# Processed file 9_theo_12.wav
# Processed file 5_george_39.wav
# Processed file 7_theo_42.wav
# Processed file 7_nicolas_40.wav
# Processed file 9_nicolas_32.wav
# Processed file 9_jackson_5.wav
# Processed file 1_theo_11.wav
# Processed file 9_george_23.wav
# Processed file 6_nicolas_7.wav
# Processed file 1_lucas_5.wav
# Processed file 4_nicolas_31.wav
# Processed file 2_theo_4.wav
# Processed file 7_theo_1.wav
# Processed file 8_george_24.wav
# Processed file 0_yweweler_32.wav
# Processed file 0_jackson_46.wav
# Processed file 3_yweweler_6.wav
# Processed file 2_theo_42.wav
# Processed file 8_theo_4.wav
# Processed file 5_jackson_24.wav
# Processed file 1_jackson_24.wav
# Processed file 5_george_22.wav
# Processed file 3_lucas_0.wav
# Processed file 9_george_20.wav
# Processed file 5_theo_36.wav
# Processed file 5_george_4.wav
# Processed file 7_theo_32.wav
# Processed file 1_theo_20.wav
# Processed file 6_jackson_20.wav
# Processed file 0_lucas_0.wav
# Processed file 4_nicolas_6.wav
# Processed file 5_theo_49.wav
# Processed file 4_lucas_46.wav
# Processed file 7_george_42.wav
# Processed file 2_nicolas_26.wav
# Processed file 0_nicolas_20.wav
# Processed file 5_theo_23.wav
# Processed file 3_george_31.wav
# Processed file 9_george_37.wav
# Processed file 9_yweweler_7.wav
# Processed file 1_yweweler_34.wav
# Processed file 2_lucas_39.wav
# Processed file 9_theo_10.wav
# Processed file 2_jackson_40.wav
# Processed file 9_lucas_22.wav
# Processed file 4_jackson_12.wav
# Processed file 0_jackson_12.wav
# Processed file 5_nicolas_45.wav
# Processed file 1_jackson_8.wav
# Processed file 0_lucas_7.wav
# Processed file 8_jackson_26.wav
# Processed file 0_lucas_48.wav
# Processed file 7_theo_31.wav
# Processed file 7_theo_27.wav
# Processed file 8_jackson_28.wav
# Processed file 4_yweweler_45.wav
# Processed file 1_jackson_17.wav
# Processed file 2_jackson_49.wav
# Processed file 7_nicolas_39.wav
# Processed file 0_jackson_13.wav
# Processed file 1_yweweler_35.wav
# Processed file 0_jackson_41.wav
# Processed file 4_yweweler_26.wav
# Processed file 8_jackson_12.wav
# Processed file 3_lucas_21.wav
# Processed file 9_jackson_0.wav
# Processed file 8_yweweler_38.wav
# Processed file 1_nicolas_15.wav
# Processed file 9_theo_22.wav
# Processed file 2_nicolas_6.wav
# Processed file 9_theo_32.wav
# Processed file 7_george_44.wav
# Processed file 8_lucas_17.wav
# Processed file 1_jackson_18.wav
# Processed file 8_jackson_20.wav
# Processed file 9_nicolas_48.wav
# Processed file 8_yweweler_26.wav
# Processed file 8_yweweler_36.wav
# Processed file 6_jackson_14.wav
# Processed file 3_theo_14.wav
# Processed file 8_jackson_33.wav
# Processed file 4_lucas_49.wav
# Processed file 8_lucas_41.wav
# Processed file 6_theo_24.wav
# Processed file 4_yweweler_17.wav
# Processed file 4_nicolas_47.wav
# Processed file 1_lucas_8.wav
# Processed file 1_george_31.wav
# Processed file 2_nicolas_13.wav
# Processed file 7_nicolas_2.wav
# Processed file 8_yweweler_25.wav
# Processed file 9_theo_30.wav
# Processed file 6_yweweler_26.wav
# Processed file 8_yweweler_16.wav
# Processed file 3_jackson_43.wav
# Processed file 1_nicolas_44.wav
# Processed file 9_theo_24.wav
# Processed file 3_nicolas_18.wav
# Processed file 9_jackson_3.wav
# Processed file 4_nicolas_19.wav
# Processed file 2_jackson_24.wav
# Processed file 8_jackson_0.wav
# Processed file 5_yweweler_35.wav
# Processed file 8_lucas_44.wav
# Processed file 5_george_26.wav
# Processed file 8_nicolas_16.wav
# Processed file 9_jackson_16.wav
# Processed file 1_nicolas_18.wav
# Processed file 0_yweweler_1.wav
# Processed file 3_george_38.wav
# Processed file 2_jackson_19.wav
# Processed file 9_yweweler_42.wav
# Processed file 4_theo_23.wav
# Processed file 4_yweweler_12.wav
# Processed file 1_theo_12.wav
# Processed file 6_yweweler_48.wav
# Processed file 9_yweweler_27.wav
# Processed file 3_theo_8.wav
# Processed file 8_lucas_5.wav
# Processed file 7_lucas_12.wav
# Processed file 9_jackson_2.wav
# Processed file 8_george_1.wav
# Processed file 2_lucas_41.wav
# Processed file 4_jackson_11.wav
# Processed file 8_nicolas_22.wav
# Processed file 1_yweweler_11.wav
# Processed file 8_jackson_10.wav
# Processed file 0_nicolas_16.wav
# Processed file 5_yweweler_37.wav
# Processed file 7_jackson_21.wav
# Processed file 9_yweweler_49.wav
# Processed file 1_nicolas_5.wav
# Processed file 2_lucas_47.wav
# Processed file 7_nicolas_36.wav
# Processed file 4_george_30.wav
# Processed file 9_george_28.wav
# Processed file 0_lucas_37.wav
# Processed file 4_yweweler_13.wav
# Processed file 6_theo_8.wav
# Processed file 5_jackson_12.wav
# Processed file 9_nicolas_46.wav
# Processed file 5_lucas_11.wav
# Processed file 9_yweweler_36.wav
# Processed file 6_lucas_20.wav
# Processed file 3_lucas_44.wav
# Processed file 0_yweweler_15.wav
# Processed file 5_jackson_0.wav
# Processed file 6_lucas_37.wav
# Processed file 3_yweweler_28.wav
# Processed file 4_jackson_17.wav
# Processed file 5_george_7.wav
# Processed file 1_jackson_7.wav
# Processed file 7_george_23.wav
# Processed file 3_george_47.wav
# Processed file 4_lucas_23.wav
# Processed file 1_nicolas_4.wav
# Processed file 4_theo_13.wav
# Processed file 1_jackson_2.wav
# Processed file 8_lucas_4.wav
# Processed file 6_yweweler_24.wav
# Processed file 0_theo_1.wav
# Processed file 8_lucas_31.wav
# Processed file 8_yweweler_33.wav
# Processed file 7_jackson_18.wav
# Processed file 6_theo_18.wav
# Processed file 1_lucas_27.wav
# Processed file 3_nicolas_16.wav
# Processed file 4_theo_18.wav
# Processed file 8_lucas_32.wav
# Processed file 0_lucas_41.wav
# Processed file 0_jackson_38.wav
# Processed file 1_george_15.wav
# Processed file 8_george_20.wav
# Processed file 9_lucas_23.wav
# Processed file 2_lucas_38.wav
# Processed file 5_lucas_42.wav
# Processed file 3_theo_36.wav
# Processed file 7_nicolas_26.wav
# Processed file 1_lucas_0.wav
# Processed file 3_theo_1.wav
# Processed file 7_theo_30.wav
# Processed file 7_theo_19.wav
# Processed file 2_theo_34.wav
# Processed file 0_yweweler_28.wav
# Processed file 9_george_4.wav
# Processed file 6_george_34.wav
# Processed file 0_lucas_46.wav
# Processed file 8_lucas_11.wav
# Processed file 1_theo_36.wav
# Processed file 8_george_18.wav
# Processed file 1_jackson_34.wav
# Processed file 8_lucas_7.wav
# Processed file 8_theo_5.wav
# Processed file 8_jackson_42.wav
# Processed file 1_nicolas_28.wav
# Processed file 9_lucas_45.wav
# Processed file 3_yweweler_26.wav
# Processed file 2_nicolas_3.wav
# Processed file 6_nicolas_45.wav
# Processed file 5_jackson_42.wav
# Processed file 2_jackson_36.wav
# Processed file 6_theo_47.wav
# Processed file 2_jackson_26.wav
# Processed file 3_jackson_27.wav
# Processed file 5_theo_19.wav
# Processed file 2_theo_12.wav
# Processed file 5_theo_0.wav
# Processed file 2_nicolas_4.wav
# Processed file 2_george_9.wav
# Processed file 5_lucas_17.wav
# Processed file 5_lucas_41.wav
# Processed file 2_jackson_28.wav
# Processed file 0_nicolas_0.wav
# Processed file 7_lucas_9.wav
# Processed file 4_nicolas_9.wav
# Processed file 9_jackson_40.wav
# Processed file 5_lucas_40.wav
# Processed file 3_yweweler_47.wav
# Processed file 7_jackson_35.wav
# Processed file 8_theo_27.wav
# Processed file 3_lucas_8.wav
# Processed file 5_theo_25.wav
# Processed file 9_theo_25.wav
# Processed file 5_george_18.wav
# Processed file 4_lucas_5.wav
# Processed file 7_yweweler_7.wav
# Processed file 2_nicolas_42.wav
# Processed file 3_theo_18.wav
# Processed file 5_theo_15.wav
# Processed file 5_nicolas_1.wav
# Processed file 5_nicolas_32.wav
# Processed file 5_theo_24.wav
# Processed file 8_george_23.wav
# Processed file 0_theo_38.wav
# Processed file 2_jackson_22.wav
# Processed file 4_lucas_15.wav
# Processed file 1_yweweler_17.wav
# Processed file 2_lucas_6.wav
# Processed file 8_lucas_49.wav
# Processed file 6_yweweler_7.wav
# Processed file 4_nicolas_29.wav
# Processed file 8_theo_25.wav
# Processed file 2_george_42.wav
# Processed file 8_nicolas_2.wav
# Processed file 3_yweweler_18.wav
# Processed file 5_jackson_20.wav
# Processed file 3_nicolas_34.wav
# Processed file 2_george_12.wav
# Processed file 8_lucas_39.wav
# Processed file 1_lucas_48.wav
# Processed file 2_theo_25.wav
# Processed file 8_yweweler_40.wav
# Processed file 3_yweweler_15.wav
# Processed file 4_jackson_45.wav
# Processed file 8_yweweler_2.wav
# Processed file 6_lucas_18.wav
# Processed file 6_theo_19.wav
# Processed file 2_nicolas_19.wav
# Processed file 4_nicolas_0.wav
# Processed file 7_theo_16.wav
# Processed file 9_jackson_41.wav
# Processed file 5_george_10.wav
# Processed file 6_nicolas_1.wav
# Processed file 0_lucas_5.wav
# Processed file 6_nicolas_32.wav
# Processed file 3_yweweler_12.wav
# Processed file 3_theo_45.wav
# Processed file 6_george_25.wav
# Processed file 9_theo_15.wav
# Processed file 6_yweweler_10.wav
# Processed file 7_lucas_21.wav
# Processed file 1_jackson_45.wav
# Processed file 1_jackson_5.wav
# Processed file 4_nicolas_5.wav
# Processed file 7_lucas_5.wav
# Processed file 3_nicolas_30.wav
# Processed file 6_yweweler_45.wav
# Processed file 5_jackson_30.wav
# Processed file 5_lucas_12.wav
# Processed file 6_lucas_8.wav
# Processed file 9_lucas_35.wav
# Processed file 3_george_36.wav
# Processed file 5_george_41.wav
# Processed file 9_lucas_24.wav
# Processed file 6_george_48.wav
# Processed file 6_jackson_18.wav
# Processed file 7_lucas_44.wav
# Processed file 6_theo_41.wav
# Processed file 3_yweweler_40.wav
# Processed file 0_nicolas_29.wav
# Processed file 2_theo_6.wav
# Processed file 1_lucas_13.wav
# Processed file 3_george_3.wav
# Processed file 5_theo_26.wav
# Processed file 0_lucas_26.wav
# Processed file 2_george_46.wav
# Processed file 9_theo_42.wav
# Processed file 5_theo_47.wav
# Processed file 6_theo_20.wav
# Processed file 2_lucas_18.wav
# Processed file 8_theo_36.wav
# Processed file 4_jackson_15.wav
# Processed file 0_yweweler_40.wav
# Processed file 7_theo_29.wav
# Processed file 4_george_43.wav
# Processed file 6_yweweler_16.wav
# Processed file 7_lucas_26.wav
# Processed file 3_lucas_1.wav
# Processed file 4_yweweler_40.wav
# Processed file 2_jackson_16.wav
# Processed file 2_george_48.wav
# Processed file 7_george_49.wav
# Processed file 7_yweweler_10.wav
# Processed file 9_yweweler_21.wav
# Processed file 5_jackson_32.wav
# Processed file 3_theo_43.wav
# Processed file 4_george_33.wav
# Processed file 5_lucas_33.wav
# Processed file 7_jackson_6.wav
# Processed file 2_jackson_25.wav
# Processed file 0_george_6.wav
# Processed file 0_theo_35.wav
# Processed file 5_yweweler_7.wav
# Processed file 0_yweweler_47.wav
# Processed file 2_lucas_15.wav
# Processed file 7_george_16.wav
# Processed file 9_nicolas_40.wav
# Processed file 4_yweweler_48.wav
# Processed file 7_yweweler_33.wav
# Processed file 6_george_4.wav
# Processed file 9_yweweler_1.wav
# Processed file 8_jackson_4.wav
# Processed file 5_lucas_22.wav
# Processed file 7_yweweler_49.wav
# Processed file 0_george_24.wav
# Processed file 7_nicolas_15.wav
# Processed file 8_lucas_35.wav
# Processed file 4_lucas_19.wav
# Processed file 5_jackson_48.wav
# Processed file 6_george_18.wav
# Processed file 4_nicolas_28.wav
# Processed file 9_george_45.wav
# Processed file 1_nicolas_10.wav
# Processed file 8_theo_34.wav
# Processed file 3_yweweler_22.wav
# Processed file 2_theo_9.wav
# Processed file 6_nicolas_6.wav
# Processed file 4_jackson_41.wav
# Processed file 2_yweweler_40.wav
# Processed file 0_nicolas_19.wav
# Processed file 9_george_27.wav
# Processed file 4_george_16.wav
# Processed file 7_jackson_12.wav
# Processed file 8_nicolas_45.wav
# Processed file 2_yweweler_20.wav
# Processed file 3_yweweler_20.wav
# Processed file 4_nicolas_23.wav
# Processed file 8_george_45.wav
# Processed file 2_george_23.wav
# Processed file 5_george_14.wav
# Processed file 6_theo_27.wav
# Processed file 6_jackson_35.wav
# Processed file 1_theo_23.wav
# Processed file 6_george_10.wav
# Processed file 0_nicolas_14.wav
# Processed file 3_george_25.wav
# Processed file 5_lucas_20.wav
# Processed file 9_george_44.wav
# Processed file 8_nicolas_1.wav
# Processed file 2_lucas_27.wav
# Processed file 1_jackson_38.wav
# Processed file 2_nicolas_34.wav
# Processed file 4_theo_27.wav
# Processed file 6_lucas_34.wav
# Processed file 2_george_35.wav
# Processed file 3_george_39.wav
# Processed file 1_nicolas_6.wav
# Processed file 3_jackson_13.wav
# Processed file 7_nicolas_3.wav
# Processed file 5_yweweler_4.wav
# Processed file 3_theo_35.wav
# Processed file 6_jackson_22.wav
# Processed file 3_george_13.wav
# Processed file 6_lucas_49.wav
# Processed file 9_george_13.wav
# Processed file 0_theo_6.wav
# Processed file 1_jackson_32.wav
# Processed file 5_nicolas_24.wav
# Processed file 8_george_0.wav
# Processed file 6_nicolas_49.wav
# Processed file 7_yweweler_32.wav
# Processed file 1_jackson_6.wav
# Processed file 2_george_14.wav
# Processed file 9_theo_13.wav
# Processed file 7_jackson_27.wav
# Processed file 6_jackson_5.wav
# Processed file 6_lucas_40.wav
# Processed file 3_yweweler_10.wav
# Processed file 2_jackson_32.wav
# Processed file 1_george_7.wav
# Processed file 9_lucas_19.wav
# Processed file 1_nicolas_43.wav
# Processed file 3_yweweler_36.wav
# Processed file 7_theo_17.wav
# Processed file 3_nicolas_10.wav
# Processed file 4_lucas_27.wav
# Processed file 0_nicolas_46.wav
# Processed file 3_george_12.wav
# Processed file 3_lucas_34.wav
# Processed file 8_nicolas_28.wav
# Processed file 8_nicolas_26.wav
# Processed file 9_george_15.wav
# Processed file 8_lucas_23.wav
# Processed file 2_nicolas_30.wav
# Processed file 6_jackson_48.wav
# Processed file 4_nicolas_36.wav
# Processed file 0_lucas_1.wav
# Processed file 2_yweweler_30.wav
# Processed file 0_yweweler_45.wav
# Processed file 7_nicolas_42.wav
# Processed file 2_george_5.wav
# Processed file 5_lucas_39.wav
# Processed file 3_theo_15.wav
# Processed file 9_yweweler_2.wav
# Processed file 4_jackson_34.wav
# Processed file 7_theo_39.wav
# Processed file 8_george_33.wav
# Processed file 2_jackson_23.wav
# Processed file 4_jackson_18.wav
# Processed file 9_nicolas_0.wav
# Processed file 7_nicolas_22.wav
# Processed file 5_nicolas_26.wav
# Processed file 8_george_42.wav
# Processed file 7_theo_21.wav
# Processed file 5_lucas_15.wav
# Processed file 6_yweweler_13.wav
# Processed file 6_lucas_0.wav
# Processed file 5_jackson_39.wav
# Processed file 1_george_43.wav
# Processed file 7_nicolas_7.wav
# Processed file 7_theo_14.wav
# Processed file 7_jackson_32.wav
# Processed file 1_lucas_26.wav
# Processed file 3_george_27.wav
# Processed file 6_jackson_8.wav
# Processed file 2_lucas_8.wav
# Processed file 9_yweweler_44.wav
# Processed file 1_george_44.wav
# Processed file 0_lucas_43.wav
# Processed file 4_jackson_3.wav
# Processed file 9_jackson_32.wav
# Processed file 9_theo_35.wav
# Processed file 2_george_32.wav
# Processed file 1_jackson_33.wav
# Processed file 5_nicolas_41.wav
# Processed file 3_lucas_37.wav
# Processed file 2_nicolas_1.wav
# Processed file 1_nicolas_9.wav
# Processed file 0_lucas_8.wav
# Processed file 2_george_31.wav
# Processed file 0_yweweler_46.wav
# Processed file 7_theo_9.wav
# Processed file 3_theo_48.wav
# Processed file 4_lucas_39.wav
# Processed file 4_jackson_5.wav
# Processed file 0_nicolas_38.wav
# Processed file 8_jackson_3.wav
# Processed file 8_lucas_14.wav
# Processed file 7_jackson_25.wav
# Processed file 8_lucas_2.wav
# Processed file 2_jackson_27.wav
# Processed file 4_george_22.wav
# Processed file 8_theo_41.wav
# Processed file 4_theo_20.wav
# Processed file 5_theo_11.wav
# Processed file 2_jackson_5.wav
# Processed file 4_nicolas_33.wav
# Processed file 9_george_7.wav
# Processed file 7_theo_34.wav
# Processed file 5_lucas_49.wav
# Processed file 6_george_38.wav
# Processed file 6_nicolas_33.wav
# Processed file 7_george_32.wav
# Processed file 5_lucas_32.wav
# Processed file 0_george_34.wav
# Processed file 6_george_9.wav
# Processed file 8_theo_16.wav
# Processed file 9_theo_44.wav
# Processed file 0_nicolas_17.wav
# Processed file 2_theo_29.wav
# Processed file 0_george_37.wav
# Processed file 3_jackson_24.wav
# Processed file 7_george_39.wav
# Processed file 8_yweweler_42.wav
# Processed file 3_jackson_41.wav
# Processed file 5_lucas_25.wav
# Processed file 5_george_45.wav
# Processed file 6_lucas_10.wav
# Processed file 4_theo_29.wav
# Processed file 6_lucas_31.wav
# Processed file 5_jackson_40.wav
# Processed file 0_george_9.wav
# Processed file 1_theo_37.wav
# Processed file 9_george_18.wav
# Processed file 2_jackson_7.wav
# Processed file 0_theo_44.wav
# Processed file 0_yweweler_39.wav
# Processed file 8_theo_18.wav
# Processed file 2_lucas_26.wav
# Processed file 7_theo_44.wav
# Processed file 9_theo_7.wav
# Processed file 5_george_19.wav
# Processed file 4_nicolas_49.wav
# Processed file 0_theo_47.wav
# Processed file 5_jackson_17.wav
# Processed file 2_jackson_14.wav
# Processed file 7_jackson_29.wav
# Processed file 7_lucas_31.wav
# Processed file 5_theo_33.wav
# Processed file 8_yweweler_30.wav
# Processed file 6_yweweler_1.wav
# Processed file 0_jackson_0.wav
# Processed file 9_george_12.wav
# Processed file 0_jackson_7.wav
# Processed file 6_nicolas_47.wav
# Processed file 4_jackson_31.wav
# Processed file 5_lucas_6.wav
# Processed file 8_jackson_49.wav
# Processed file 1_jackson_44.wav
# Processed file 1_yweweler_39.wav
# Processed file 7_george_8.wav
# Processed file 6_yweweler_15.wav
# Processed file 2_yweweler_6.wav
# Processed file 7_jackson_9.wav
# Processed file 2_theo_47.wav
# Processed file 5_jackson_44.wav
# Processed file 2_nicolas_49.wav
# Processed file 5_george_16.wav
# Processed file 1_george_23.wav
# Processed file 0_jackson_1.wav
# Processed file 9_george_39.wav
# Processed file 7_nicolas_6.wav
# Processed file 9_lucas_14.wav
# Processed file 9_yweweler_15.wav
# Processed file 3_yweweler_21.wav
# Processed file 5_yweweler_24.wav
# Processed file 6_george_19.wav
# Processed file 6_lucas_39.wav
# Processed file 8_theo_0.wav
# Processed file 7_lucas_23.wav
# Processed file 6_jackson_32.wav
# Processed file 7_theo_45.wav
# Processed file 3_theo_34.wav
# Processed file 5_nicolas_34.wav
# Processed file 9_jackson_4.wav
# Processed file 3_nicolas_8.wav
# Processed file 2_yweweler_9.wav
# Processed file 8_george_6.wav
# Processed file 7_lucas_48.wav
# Processed file 4_yweweler_8.wav
# Processed file 5_george_43.wav
# Processed file 2_nicolas_35.wav
# Processed file 2_lucas_10.wav
# Processed file 0_nicolas_45.wav
# Processed file 6_yweweler_35.wav
# Processed file 7_jackson_31.wav
# Processed file 8_george_37.wav
# Processed file 3_lucas_45.wav
# Processed file 7_theo_10.wav
# Processed file 6_yweweler_46.wav
# Processed file 0_lucas_38.wav
# Processed file 0_yweweler_21.wav
# Processed file 3_george_33.wav
# Processed file 4_lucas_24.wav
# Processed file 8_theo_33.wav
# Processed file 0_jackson_18.wav
# Processed file 7_nicolas_23.wav
# Processed file 7_yweweler_19.wav
# Processed file 5_nicolas_36.wav
# Processed file 1_yweweler_46.wav
# Processed file 6_lucas_6.wav
# Processed file 0_yweweler_14.wav
# Processed file 6_nicolas_34.wav
# Processed file 7_lucas_49.wav
# Processed file 1_george_12.wav
# Processed file 4_theo_8.wav
# Processed file 3_george_0.wav
# Processed file 5_nicolas_40.wav
# Processed file 5_jackson_34.wav
# Processed file 7_george_1.wav
# Processed file 0_jackson_9.wav
# Processed file 9_yweweler_17.wav
# Processed file 7_yweweler_30.wav
# Processed file 1_lucas_18.wav
# Processed file 3_lucas_36.wav
# Processed file 4_lucas_4.wav
# Processed file 5_theo_4.wav
# Processed file 4_theo_49.wav
# Processed file 8_nicolas_34.wav
# Processed file 9_nicolas_45.wav
# Processed file 1_lucas_41.wav
# Processed file 7_jackson_28.wav
# Processed file 2_yweweler_45.wav
# Processed file 8_theo_44.wav
# Processed file 4_theo_47.wav
# Processed file 4_yweweler_9.wav
# Processed file 9_jackson_20.wav
# Processed file 7_lucas_37.wav
# Processed file 4_yweweler_31.wav
# Processed file 9_nicolas_36.wav
# Processed file 1_george_35.wav
# Processed file 2_jackson_17.wav
# Processed file 5_george_47.wav
# Processed file 5_nicolas_6.wav
# Processed file 4_theo_38.wav
# Processed file 6_george_45.wav
# Processed file 5_jackson_9.wav
# Processed file 7_lucas_36.wav
# Processed file 3_nicolas_46.wav
# Processed file 4_jackson_47.wav
# Processed file 2_george_19.wav
# Processed file 3_jackson_3.wav
# Processed file 3_jackson_7.wav
# Processed file 0_lucas_22.wav
# Processed file 9_yweweler_29.wav
# Processed file 5_yweweler_36.wav
# Processed file 3_nicolas_42.wav
# Processed file 2_theo_21.wav
# Processed file 7_george_41.wav
# Processed file 4_theo_15.wav
# Processed file 6_nicolas_4.wav
# Processed file 2_nicolas_16.wav
# Processed file 4_yweweler_11.wav
# Processed file 2_george_24.wav
# Processed file 7_jackson_33.wav
# Processed file 6_jackson_46.wav
# Processed file 4_nicolas_44.wav
# Processed file 3_theo_38.wav
# Processed file 0_jackson_10.wav
# Processed file 4_yweweler_35.wav
# Processed file 8_yweweler_6.wav
# Processed file 0_george_13.wav
# Processed file 4_lucas_30.wav
# Processed file 7_nicolas_38.wav
# Processed file 0_theo_9.wav
# Processed file 3_george_23.wav
# Processed file 8_lucas_12.wav
# Processed file 1_nicolas_13.wav
# Processed file 9_jackson_49.wav
# Processed file 0_george_15.wav
# Processed file 8_nicolas_5.wav
# Processed file 3_jackson_42.wav
# Processed file 7_nicolas_32.wav
# Processed file 5_lucas_3.wav
# Processed file 1_theo_27.wav
# Processed file 7_lucas_3.wav
# Processed file 9_george_46.wav
# Processed file 0_jackson_3.wav
# Processed file 0_nicolas_28.wav
# Processed file 4_nicolas_46.wav
# Processed file 1_george_46.wav
# Processed file 1_george_38.wav
# Processed file 8_nicolas_33.wav
# Processed file 3_lucas_6.wav
# Processed file 5_george_31.wav
# Processed file 7_yweweler_36.wav
# Processed file 4_yweweler_16.wav
# Processed file 2_george_40.wav
# Processed file 2_lucas_30.wav
# Processed file 6_theo_44.wav
# Processed file 5_nicolas_7.wav
# Processed file 2_jackson_11.wav
# Processed file 5_george_25.wav
# Processed file 2_yweweler_37.wav
# Processed file 1_yweweler_21.wav
# Processed file 4_theo_1.wav
# Processed file 3_nicolas_7.wav
# Processed file 2_theo_39.wav
# Processed file 9_yweweler_12.wav
# Processed file 0_nicolas_24.wav
# Processed file 3_theo_25.wav
# Processed file 5_nicolas_0.wav
# Processed file 9_nicolas_42.wav
# Processed file 5_theo_38.wav
# Processed file 8_yweweler_31.wav
# Processed file 8_yweweler_27.wav
# Processed file 9_theo_47.wav
# Processed file 7_yweweler_18.wav
# Processed file 8_jackson_41.wav
# Processed file 9_jackson_24.wav
# Processed file 4_george_37.wav
# Processed file 3_george_48.wav
# Processed file 3_lucas_20.wav
# Processed file 0_george_44.wav
# Processed file 4_george_5.wav
# Processed file 5_theo_9.wav
# Processed file 0_george_0.wav
# Processed file 0_theo_2.wav
# Processed file 3_nicolas_21.wav
# Processed file 1_yweweler_37.wav
# Processed file 3_yweweler_33.wav
# Processed file 4_yweweler_0.wav
# Processed file 4_nicolas_42.wav
# Processed file 6_jackson_27.wav
# Processed file 8_lucas_47.wav
# Processed file 3_nicolas_39.wav
# Processed file 3_george_10.wav
# Processed file 9_yweweler_9.wav
# Processed file 5_yweweler_42.wav
# Processed file 6_yweweler_30.wav
# Processed file 7_george_34.wav
# Processed file 5_nicolas_10.wav
# Processed file 2_jackson_18.wav
# Processed file 1_theo_3.wav
# Processed file 1_jackson_48.wav
# Processed file 4_theo_31.wav
# Processed file 0_jackson_19.wav
# Processed file 9_theo_34.wav
# Processed file 8_jackson_19.wav
# Processed file 6_george_2.wav
# Processed file 9_theo_39.wav
# Processed file 2_george_41.wav
# Processed file 5_nicolas_27.wav
# Processed file 2_yweweler_13.wav
# Processed file 6_jackson_33.wav
# Processed file 1_lucas_25.wav
# Processed file 2_nicolas_27.wav
# Processed file 1_theo_40.wav
# Processed file 6_yweweler_0.wav
# Processed file 3_theo_7.wav
# Processed file 9_lucas_39.wav
# Processed file 9_lucas_42.wav
# Processed file 5_yweweler_40.wav
# Processed file 3_lucas_43.wav
# Processed file 5_lucas_35.wav
# Processed file 9_lucas_5.wav
# Processed file 0_theo_40.wav
# Processed file 4_lucas_9.wav
# Processed file 9_lucas_40.wav
# Processed file 5_jackson_35.wav
# Processed file 4_yweweler_34.wav
# Processed file 3_lucas_9.wav
# Processed file 1_nicolas_48.wav
# Processed file 4_nicolas_25.wav
# Processed file 8_nicolas_21.wav
# Processed file 6_theo_12.wav
# Processed file 7_nicolas_10.wav
# Processed file 8_theo_26.wav
# Processed file 5_jackson_41.wav
# Processed file 7_nicolas_5.wav
# Processed file 6_yweweler_33.wav
# Processed file 2_george_6.wav
# Processed file 2_lucas_29.wav
# Processed file 3_jackson_14.wav
# Processed file 5_lucas_4.wav
# Processed file 0_lucas_24.wav
# Processed file 1_theo_25.wav
# Processed file 4_lucas_8.wav
# Processed file 7_nicolas_29.wav
# Processed file 8_jackson_32.wav
# Processed file 5_yweweler_31.wav
# Processed file 3_nicolas_17.wav
# Processed file 4_nicolas_32.wav
# Processed file 8_lucas_1.wav
# Processed file 5_lucas_18.wav
# Processed file 0_jackson_20.wav
# Processed file 3_theo_27.wav
# Processed file 1_lucas_40.wav
# Processed file 8_theo_7.wav
# Processed file 8_theo_37.wav
# Processed file 1_yweweler_3.wav
# Processed file 6_george_6.wav
# Processed file 1_nicolas_47.wav
# Processed file 1_jackson_40.wav
# Processed file 5_jackson_29.wav
# Processed file 6_george_20.wav
# Processed file 4_nicolas_35.wav
# Processed file 7_george_17.wav
# Processed file 5_theo_34.wav
# Processed file 8_yweweler_49.wav
# Processed file 6_yweweler_9.wav
# Processed file 1_george_14.wav
# Processed file 2_lucas_48.wav
# Processed file 0_lucas_32.wav
# Processed file 8_nicolas_0.wav
# Processed file 0_theo_29.wav
# Processed file 4_lucas_25.wav
# Processed file 6_jackson_2.wav
# Processed file 8_theo_49.wav
# Processed file 5_george_2.wav
# Processed file 4_theo_46.wav
# Processed file 5_yweweler_9.wav
# Processed file 0_jackson_32.wav
# Processed file 3_nicolas_1.wav
# Processed file 2_theo_23.wav
# Processed file 9_george_34.wav
# Processed file 7_theo_48.wav
# Processed file 0_lucas_9.wav
# Processed file 3_george_28.wav
# Processed file 1_george_18.wav
# Processed file 3_theo_12.wav
# Processed file 0_nicolas_43.wav
# Processed file 3_jackson_20.wav
# Processed file 6_jackson_13.wav
# Processed file 8_jackson_17.wav
# Processed file 0_jackson_47.wav
# Processed file 6_jackson_9.wav
# Processed file 4_george_25.wav
# Processed file 4_theo_4.wav
# Processed file 4_theo_11.wav
# Processed file 5_george_9.wav
# Processed file 4_lucas_32.wav
# Processed file 6_yweweler_40.wav
# Processed file 2_george_38.wav
# Processed file 8_nicolas_32.wav
# Processed file 6_lucas_43.wav
# Processed file 2_yweweler_23.wav
# Processed file 0_lucas_28.wav
# Processed file 3_yweweler_45.wav
# Processed file 2_lucas_3.wav
# Processed file 3_yweweler_43.wav
# Processed file 4_lucas_7.wav
# Processed file 4_lucas_6.wav
# Processed file 2_yweweler_29.wav
# Processed file 1_theo_29.wav
# Processed file 1_theo_43.wav
# Processed file 3_yweweler_25.wav
# Processed file 1_nicolas_34.wav
# Processed file 6_george_13.wav
# Processed file 6_theo_22.wav
# Processed file 4_theo_40.wav
# Processed file 6_jackson_28.wav
# Processed file 3_theo_33.wav
# Processed file 4_jackson_20.wav
# Processed file 6_theo_9.wav
# Processed file 2_lucas_16.wav
# Processed file 7_lucas_43.wav
# Processed file 4_nicolas_15.wav
# Processed file 7_jackson_13.wav
# Processed file 1_george_37.wav
# Processed file 8_lucas_24.wav
# Processed file 1_theo_24.wav
# Processed file 8_lucas_22.wav
# Processed file 8_yweweler_11.wav
# Processed file 8_theo_8.wav
# Processed file 6_yweweler_5.wav
# Processed file 7_george_43.wav
# Processed file 6_george_0.wav
# Processed file 9_george_40.wav
# Processed file 9_george_14.wav
# Processed file 1_george_27.wav
# Processed file 2_yweweler_38.wav
# Processed file 3_nicolas_27.wav
# Processed file 7_nicolas_34.wav
# Processed file 8_yweweler_39.wav
# Processed file 4_nicolas_20.wav
# Processed file 9_lucas_4.wav
# Processed file 0_yweweler_22.wav
# Processed file 1_nicolas_23.wav
# Processed file 4_jackson_44.wav
# Processed file 4_yweweler_27.wav
# Processed file 8_theo_21.wav
# Processed file 9_nicolas_34.wav
# Processed file 5_nicolas_3.wav
# Processed file 2_george_4.wav
# Processed file 4_lucas_21.wav
# Processed file 0_theo_11.wav
# Processed file 6_jackson_3.wav
# Processed file 8_george_10.wav
# Processed file 0_yweweler_18.wav
# Processed file 2_nicolas_28.wav
# Processed file 4_theo_21.wav
# Processed file 2_george_7.wav
# Processed file 3_lucas_30.wav
# Processed file 5_theo_20.wav
# Processed file 2_george_0.wav
# Processed file 6_jackson_37.wav
# Processed file 9_nicolas_10.wav
# Processed file 2_lucas_0.wav
# Processed file 9_nicolas_16.wav
# Processed file 0_nicolas_7.wav
# Processed file 0_yweweler_6.wav
# Processed file 9_jackson_12.wav
# Processed file 5_theo_5.wav
# Processed file 2_theo_40.wav
# Processed file 6_yweweler_39.wav
# Processed file 9_yweweler_48.wav
# Processed file 9_theo_28.wav
# Processed file 6_jackson_7.wav
# Processed file 2_lucas_20.wav
# Processed file 4_george_20.wav
# Processed file 1_jackson_41.wav
# Processed file 9_nicolas_23.wav
# Processed file 6_nicolas_48.wav
# Processed file 1_lucas_36.wav
# Processed file 0_george_48.wav
# Processed file 5_theo_44.wav
# Processed file 6_theo_26.wav
# Processed file 3_nicolas_11.wav
# Processed file 4_jackson_0.wav
# Processed file 2_lucas_24.wav
# Processed file 2_lucas_1.wav
# Processed file 6_lucas_27.wav
# Processed file 5_jackson_28.wav
# Processed file 1_theo_18.wav
# Processed file 0_nicolas_21.wav
# Processed file 5_theo_6.wav
# Processed file 1_george_0.wav
# Processed file 4_george_46.wav
# Processed file 8_lucas_9.wav
# Processed file 1_yweweler_27.wav
# Processed file 4_jackson_42.wav
# Processed file 3_jackson_22.wav
# Processed file 2_yweweler_42.wav
# Processed file 5_jackson_15.wav
# Processed file 1_nicolas_25.wav
# Processed file 7_lucas_19.wav
# Processed file 8_yweweler_7.wav
# Processed file 0_theo_21.wav
# Processed file 6_theo_21.wav
# Processed file 6_lucas_45.wav
# Processed file 5_george_36.wav
# Processed file 1_theo_48.wav
# Processed file 5_george_30.wav
# Processed file 7_lucas_10.wav
# Processed file 6_nicolas_17.wav
# Processed file 1_jackson_28.wav
# Processed file 1_jackson_4.wav
# Processed file 6_yweweler_25.wav
# Processed file 7_lucas_33.wav
# Processed file 5_nicolas_42.wav
# Processed file 9_jackson_27.wav
# Processed file 7_nicolas_1.wav
# Processed file 3_george_8.wav
# Processed file 8_nicolas_44.wav
# Processed file 9_lucas_16.wav
# Processed file 9_yweweler_25.wav
# Processed file 8_yweweler_1.wav
# Processed file 7_nicolas_28.wav
# Processed file 0_nicolas_18.wav
# Processed file 2_nicolas_37.wav
# Processed file 1_nicolas_30.wav
# Processed file 5_yweweler_46.wav
# Processed file 3_lucas_3.wav
# Processed file 7_nicolas_19.wav
# Processed file 4_lucas_43.wav
# Processed file 5_lucas_34.wav
# Processed file 3_nicolas_9.wav
# Processed file 2_yweweler_19.wav
# Processed file 1_theo_49.wav
# Processed file 7_george_15.wav
# Processed file 8_jackson_14.wav
# Processed file 1_jackson_23.wav
# Processed file 5_theo_42.wav
# Processed file 3_yweweler_11.wav
# Processed file 7_lucas_34.wav
# Processed file 9_theo_16.wav
# Processed file 1_theo_2.wav
# Processed file 8_nicolas_11.wav
# Processed file 2_jackson_38.wav
# Processed file 0_yweweler_44.wav
# Processed file 8_lucas_46.wav
# Processed file 6_george_30.wav
# Processed file 0_nicolas_12.wav
# Processed file 9_lucas_37.wav
# Processed file 4_lucas_47.wav
# Processed file 7_nicolas_17.wav
# Processed file 0_george_25.wav
# Processed file 1_lucas_9.wav
# Processed file 4_jackson_23.wav
# Processed file 9_nicolas_13.wav
# Processed file 3_george_37.wav
# Processed file 1_yweweler_4.wav
# Processed file 1_george_24.wav
# Processed file 4_lucas_12.wav
# Processed file 9_theo_23.wav
# Processed file 8_theo_30.wav
# Processed file 7_theo_24.wav
# Processed file 3_lucas_4.wav
# Processed file 2_jackson_47.wav
# Processed file 9_jackson_48.wav
# Processed file 8_george_29.wav
# Processed file 5_george_33.wav
# Processed file 8_theo_15.wav
# Processed file 6_nicolas_46.wav
# Processed file 2_theo_8.wav
# Processed file 6_lucas_14.wav
# Processed file 1_george_1.wav
# Processed file 1_lucas_38.wav
# Processed file 1_yweweler_28.wav
# Processed file 1_jackson_31.wav
# Processed file 5_jackson_16.wav
# Processed file 1_george_9.wav
# Processed file 7_nicolas_18.wav
# Processed file 4_nicolas_8.wav
# Processed file 1_yweweler_9.wav
# Processed file 3_theo_26.wav
# Processed file 3_nicolas_2.wav
# Processed file 8_george_12.wav
# Processed file 6_nicolas_31.wav
# Processed file 0_george_1.wav
# Processed file 3_jackson_8.wav
# Processed file 3_george_35.wav
# Processed file 5_yweweler_26.wav
# Processed file 3_jackson_29.wav
# Processed file 9_theo_46.wav
# Processed file 2_jackson_15.wav
# Processed file 5_yweweler_13.wav
# Processed file 3_yweweler_8.wav
# Processed file 6_jackson_42.wav
# Processed file 6_theo_46.wav
# Processed file 2_yweweler_5.wav
# Processed file 4_yweweler_39.wav
# Processed file 7_yweweler_9.wav
# ...
# Processed file 0_lucas_4.wav
# Processed file 7_yweweler_1.wav
# Processed file 0_jackson_30.wav
# Processed file 0_jackson_28.wav
# Processed file 5_nicolas_21.wav
# Processed file 7_george_24.wav
# Processed file 3_jackson_47.wav
# Processed file 9_jackson_33.wav
# Processed file 8_jackson_43.wav
# Processed file 8_lucas_25.wav
# Processed file 5_george_34.wav
# Processed file 1_lucas_42.wav
# Processed file 8_lucas_28.wav
# Processed file 5_yweweler_18.wav
# Processed file 8_jackson_16.wav
# Processed file 0_george_47.wav
# Processed file 7_george_27.wav
# Processed file 0_jackson_31.wav
# Processed file 6_theo_38.wav
# Processed file 2_yweweler_49.wav
# Processed file 9_lucas_48.wav
# Processed file 1_yweweler_23.wav
# Processed file 7_yweweler_26.wav
# Processed file 5_nicolas_49.wav
# Processed file 7_george_38.wav
# Processed file 6_theo_10.wav
# Processed file 0_jackson_42.wav
# Processed file 1_lucas_22.wav
# Processed file 1_yweweler_12.wav
# Processed file 4_nicolas_38.wav
# Processed file 7_theo_8.wav
# Processed file 9_lucas_6.wav
# Processed file 2_yweweler_18.wav
# Processed file 1_yweweler_40.wav
# Processed file 0_theo_7.wav
# Processed file 6_lucas_15.wav
# Processed file 0_theo_43.wav
# Processed file 0_yweweler_20.wav
# Processed file 3_lucas_47.wav
# Processed file 4_theo_5.wav
# Processed file 0_george_32.wav
# Processed file 9_yweweler_37.wav
# Processed file 3_jackson_23.wav
# Processed file 4_yweweler_4.wav
# Processed file 3_jackson_5.wav
# Processed file 1_theo_5.wav
# Processed file 9_yweweler_6.wav
# Processed file 0_yweweler_11.wav
# Processed file 1_theo_46.wav
# Processed file 2_theo_37.wav
# Processed file 4_jackson_9.wav
# Processed file 5_theo_16.wav
# Processed file 8_jackson_30.wav
# Processed file 5_george_44.wav
# Processed file 4_george_1.wav
# Processed file 8_nicolas_14.wav
# Processed file 6_jackson_24.wav
# Processed file 2_theo_7.wav
# Processed file 0_nicolas_2.wav
# Processed file 8_lucas_34.wav
# Processed file 5_nicolas_47.wav
# Processed file 4_jackson_28.wav
# Processed file 7_george_31.wav
# Processed file 3_lucas_16.wav
# Processed file 7_jackson_43.wav
# Processed file 0_jackson_25.wav
# Processed file 2_theo_48.wav
# Processed file 7_lucas_15.wav
# Processed file 4_george_17.wav
# Processed file 8_nicolas_29.wav
# Processed file 7_lucas_46.wav
# Processed file 2_yweweler_14.wav
# Processed file 2_lucas_17.wav
# Processed file 7_george_37.wav
# Processed file 9_george_10.wav
# Processed file 0_george_26.wav
# Processed file 6_nicolas_29.wav
# Processed file 1_jackson_9.wav
# Processed file 9_theo_0.wav
# Processed file 3_jackson_21.wav
# Processed file 2_george_17.wav
# Processed file 8_theo_12.wav
# Processed file 6_george_21.wav
# Processed file 7_theo_28.wav
# Processed file 0_nicolas_4.wav
# Processed file 0_george_18.wav
# Processed file 0_nicolas_13.wav
# Processed file 8_jackson_45.wav
# Processed file 5_yweweler_2.wav
# Processed file 1_theo_8.wav
# Processed file 3_lucas_25.wav
# Processed file 7_theo_36.wav
# Processed file 8_george_13.wav
# Processed file 6_jackson_45.wav
# Processed file 0_theo_33.wav
# Processed file 5_yweweler_38.wav
# Processed file 1_jackson_35.wav
# Processed file 6_nicolas_36.wav
# Processed file 2_george_22.wav
# Processed file 2_jackson_42.wav
# Processed file 6_nicolas_22.wav
# Processed file 3_jackson_33.wav
# Processed file 3_yweweler_23.wav
# Processed file 1_yweweler_33.wav
# Processed file 0_jackson_14.wav
# Processed file 3_lucas_17.wav
# Processed file 4_george_35.wav
# Processed file 5_yweweler_33.wav
# Processed file 0_theo_18.wav
# Processed file 5_yweweler_25.wav
# Processed file 5_nicolas_20.wav
# Processed file 3_yweweler_14.wav
# Processed file 6_nicolas_19.wav
# Processed file 2_nicolas_10.wav
# Processed file 8_lucas_6.wav
# Processed file 4_nicolas_14.wav
# Processed file 2_lucas_25.wav
# Processed file 5_jackson_27.wav
# Processed file 1_nicolas_36.wav
# Processed file 4_george_32.wav
# Processed file 7_nicolas_35.wav
# Processed file 6_george_3.wav
# Processed file 6_nicolas_25.wav
# Processed file 2_george_25.wav
# Processed file 4_theo_17.wav
# Processed file 4_yweweler_33.wav
# Processed file 4_theo_48.wav
# Processed file 7_nicolas_0.wav
# Processed file 7_nicolas_24.wav
# Processed file 3_jackson_45.wav
# Processed file 2_george_13.wav
# Processed file 7_theo_15.wav
# Processed file 3_jackson_31.wav
# Processed file 4_nicolas_24.wav
# Processed file 7_yweweler_48.wav
# Processed file 2_theo_38.wav
# Processed file 5_lucas_27.wav
# Processed file 0_jackson_17.wav
# Processed file 4_theo_39.wav
# Processed file 5_george_17.wav
# Processed file 0_nicolas_6.wav
# Processed file 3_yweweler_42.wav
# Processed file 5_yweweler_44.wav
# Processed file 5_yweweler_43.wav
# Processed file 5_yweweler_48.wav
# Processed file 2_george_29.wav
# Processed file 2_yweweler_33.wav
# Processed file 8_theo_2.wav
# Processed file 0_george_17.wav
# Processed file 7_lucas_45.wav
# Processed file 6_george_15.wav
# Processed file 1_george_40.wav
# Processed file 3_nicolas_37.wav
# Processed file 8_theo_24.wav
# Processed file 1_theo_22.wav
# Processed file 7_lucas_13.wav
# Processed file 5_george_12.wav
# Processed file 4_yweweler_14.wav
# Processed file 3_george_32.wav
# Processed file 8_theo_46.wav
# Processed file 9_jackson_30.wav
# Processed file 0_theo_0.wav
# Processed file 9_nicolas_43.wav
# Processed file 6_george_27.wav
# Processed file 1_theo_7.wav
# Processed file 6_george_26.wav
# Processed file 8_nicolas_35.wav
# Processed file 9_george_2.wav
# Processed file 0_jackson_49.wav
# Processed file 0_theo_24.wav
# Processed file 6_lucas_42.wav
# Processed file 0_lucas_12.wav
# Processed file 9_george_30.wav
# Processed file 7_theo_0.wav
# Processed file 8_theo_13.wav
# Processed file 8_george_17.wav
# Processed file 8_nicolas_12.wav
# Processed file 9_lucas_11.wav
# Processed file 0_nicolas_33.wav
# Processed file 3_george_14.wav
# Processed file 0_jackson_35.wav
# Processed file 8_lucas_40.wav
# Processed file 7_yweweler_3.wav
# Processed file 8_jackson_40.wav
# Processed file 3_jackson_12.wav
# Processed file 9_jackson_9.wav
# Processed file 4_yweweler_19.wav
# Processed file 5_nicolas_30.wav
# Processed file 2_lucas_2.wav
# Processed file 9_george_5.wav
# Processed file 4_nicolas_22.wav
# Processed file 1_nicolas_46.wav
# Processed file 6_lucas_47.wav
# Processed file 7_george_7.wav
# Processed file 9_jackson_28.wav
# Processed file 5_jackson_36.wav
# Processed file 9_yweweler_30.wav
# Processed file 7_yweweler_27.wav
# Processed file 7_yweweler_11.wav
# Processed file 0_theo_26.wav
# Processed file 9_nicolas_39.wav
# Processed file 4_george_12.wav
# Processed file 5_jackson_1.wav
# Processed file 0_lucas_29.wav
# Processed file 2_yweweler_31.wav
# Processed file 7_theo_23.wav
# Processed file 1_lucas_37.wav
# Processed file 9_nicolas_44.wav
# Processed file 8_jackson_31.wav
# Processed file 1_theo_15.wav
# Processed file 0_yweweler_16.wav
# Processed file 0_lucas_47.wav
# Processed file 6_nicolas_38.wav
# Processed file 8_yweweler_3.wav
# Processed file 4_lucas_48.wav
# Processed file 1_lucas_2.wav
# Processed file 0_yweweler_30.wav
# Processed file 0_nicolas_41.wav
# Processed file 9_george_22.wav
# Processed file 1_lucas_12.wav
# Processed file 9_nicolas_31.wav
# Processed file 3_yweweler_44.wav
# Processed file 8_jackson_6.wav
# Processed file 3_jackson_11.wav
# Processed file 1_yweweler_38.wav
# Processed file 7_yweweler_40.wav
# Processed file 1_nicolas_0.wav
# Processed file 5_jackson_14.wav
# Processed file 1_jackson_27.wav
# Processed file 8_lucas_21.wav
# Processed file 5_theo_30.wav
# Processed file 9_lucas_33.wav
# Processed file 5_theo_18.wav
# Processed file 7_yweweler_39.wav
# Processed file 7_nicolas_44.wav
# Processed file 6_george_5.wav
# Processed file 4_nicolas_39.wav
# Processed file 7_nicolas_13.wav
# Processed file 6_jackson_30.wav
# Processed file 7_george_6.wav
# Processed file 3_jackson_32.wav
# Processed file 8_jackson_35.wav
# Processed file 4_nicolas_10.wav
# Processed file 1_theo_19.wav
# Processed file 8_george_8.wav
# Processed file 5_theo_22.wav
# Processed file 8_theo_10.wav
# Processed file 7_lucas_39.wav
# Processed file 5_lucas_37.wav
# Processed file 6_lucas_4.wav
# Processed file 0_nicolas_30.wav
# Processed file 9_nicolas_11.wav
# Processed file 0_nicolas_40.wav
# Processed file 8_jackson_39.wav
# Processed file 6_lucas_21.wav
# Processed file 4_lucas_29.wav
# Processed file 1_jackson_43.wav
# Processed file 8_theo_14.wav
# Processed file 6_george_37.wav
# Processed file 8_yweweler_29.wav
# Processed file 1_lucas_29.wav
# Processed file 9_lucas_10.wav
# Processed file 6_lucas_3.wav
# Processed file 1_yweweler_15.wav
# Processed file 9_jackson_23.wav
# Processed file 9_theo_14.wav
# Processed file 5_nicolas_13.wav
# Processed file 2_yweweler_32.wav
# Processed file 1_jackson_16.wav
# Processed file 9_lucas_3.wav
# Processed file 3_yweweler_16.wav
# Processed file 5_nicolas_43.wav
# Processed file 0_yweweler_9.wav
# Processed file 3_theo_21.wav
# Processed file 2_jackson_45.wav
# Processed file 7_george_33.wav
# Processed file 4_yweweler_5.wav
# Processed file 2_yweweler_41.wav
# Processed file 0_theo_42.wav
# Processed file 5_yweweler_15.wav
# Processed file 8_nicolas_40.wav
# Processed file 4_yweweler_24.wav
# Processed file 7_yweweler_44.wav
# Processed file 9_george_41.wav
# Processed file 5_nicolas_38.wav
# Processed file 9_theo_27.wav
# Processed file 0_lucas_30.wav
# Processed file 5_lucas_28.wav
# Processed file 6_lucas_44.wav
# Processed file 2_george_39.wav
# Processed file 3_jackson_17.wav
# Processed file 3_lucas_26.wav
# Processed file 0_george_49.wav
# Processed file 8_yweweler_35.wav
# Processed file 8_jackson_34.wav
# Processed file 3_nicolas_20.wav
# Processed file 8_george_27.wav
# Processed file 0_jackson_24.wav
# Processed file 1_theo_21.wav
# Processed file 8_nicolas_41.wav
# Processed file 2_jackson_21.wav
# Processed file 0_theo_17.wav
# Processed file 5_nicolas_31.wav
# Processed file 9_yweweler_18.wav
# Processed file 8_yweweler_44.wav
# Processed file 9_jackson_22.wav
# Processed file 9_jackson_35.wav
# Processed file 0_jackson_43.wav
# Processed file 1_nicolas_12.wav
# Processed file 9_yweweler_11.wav
# Processed file 5_nicolas_46.wav
# Processed file 2_george_47.wav
# Processed file 3_yweweler_24.wav
# Processed file 9_george_29.wav
# Processed file 3_george_7.wav
# Processed file 6_lucas_36.wav
# Processed file 2_yweweler_15.wav
# Processed file 1_yweweler_32.wav
# Processed file 4_theo_19.wav
# Processed file 6_george_35.wav
# Processed file 4_nicolas_21.wav
# Processed file 3_yweweler_1.wav
# Processed file 2_yweweler_4.wav
# Processed file 0_george_23.wav
# Processed file 7_jackson_4.wav
# Processed file 3_nicolas_3.wav
# Processed file 9_yweweler_28.wav
# Processed file 6_lucas_7.wav
# Processed file 7_jackson_49.wav
# Processed file 6_yweweler_11.wav
# Processed file 5_yweweler_17.wav
# Processed file 7_george_0.wav
# Processed file 3_yweweler_32.wav
# Processed file 2_yweweler_11.wav
# Processed file 0_george_21.wav
# Processed file 2_theo_27.wav
# Processed file 3_theo_44.wav
# Processed file 9_theo_6.wav
# Processed file 0_nicolas_42.wav
# Processed file 9_yweweler_3.wav
# Processed file 2_yweweler_48.wav
# Processed file 9_theo_17.wav
# Processed file 4_george_48.wav
# Processed file 2_george_43.wav
# Processed file 6_jackson_49.wav
# Processed file 0_lucas_34.wav
# Processed file 0_jackson_23.wav
# Processed file 6_yweweler_2.wav
# Processed file 7_george_13.wav
# Processed file 0_theo_4.wav
# Processed file 1_jackson_12.wav
# Processed file 4_george_11.wav
# Processed file 6_george_40.wav
# Processed file 1_nicolas_38.wav
# Processed file 9_nicolas_29.wav
# Processed file 4_yweweler_21.wav
# Processed file 2_theo_46.wav
# Processed file 9_theo_29.wav
# Processed file 4_jackson_29.wav
# Processed file 3_jackson_44.wav
# Processed file 8_lucas_26.wav
# Processed file 4_george_27.wav
# Processed file 8_yweweler_37.wav
# Processed file 6_jackson_41.wav
# Processed file 1_theo_32.wav
# Processed file 2_nicolas_18.wav
# Processed file 6_theo_42.wav
# Processed file 7_theo_35.wav
# Processed file 0_theo_10.wav
# Processed file 3_jackson_34.wav
# Processed file 5_lucas_46.wav
# Processed file 1_george_11.wav
# Processed file 4_nicolas_11.wav
# Processed file 8_theo_31.wav
# Processed file 0_nicolas_5.wav
# Processed file 8_nicolas_13.wav
# Processed file 4_yweweler_32.wav
# Processed file 2_nicolas_47.wav
# Processed file 5_nicolas_18.wav
# Processed file 2_jackson_41.wav
# Processed file 8_yweweler_43.wav
# Processed file 5_lucas_10.wav
# Processed file 1_yweweler_45.wav
# Processed file 6_george_28.wav
# Processed file 7_lucas_29.wav
# Processed file 0_yweweler_42.wav
# Processed file 5_yweweler_27.wav
# Processed file 3_jackson_35.wav
# Processed file 2_jackson_30.wav
# Processed file 4_jackson_35.wav
# Processed file 1_nicolas_49.wav
# Processed file 6_george_17.wav
# Processed file 4_jackson_38.wav
# Processed file 9_jackson_17.wav
# Processed file 0_yweweler_2.wav
# Processed file 9_lucas_31.wav
# Processed file 6_lucas_41.wav
# Processed file 5_jackson_18.wav
# Processed file 8_theo_43.wav
# Processed file 7_jackson_40.wav
# Processed file 5_yweweler_19.wav
# Processed file 5_lucas_14.wav
# Processed file 2_lucas_32.wav
# Processed file 7_theo_22.wav
# Processed file 5_george_5.wav
# Processed file 4_nicolas_41.wav
# Processed file 7_yweweler_21.wav
# Processed file 8_jackson_9.wav
# Processed file 8_george_26.wav
# Processed file 3_nicolas_49.wav
# Processed file 4_theo_25.wav
# Processed file 5_yweweler_10.wav
# Processed file 2_nicolas_39.wav
# Processed file 1_george_29.wav
# Processed file 8_jackson_15.wav
# Processed file 1_yweweler_6.wav
# Processed file 4_nicolas_12.wav
# Processed file 8_yweweler_24.wav
# Processed file 1_theo_4.wav
# Processed file 4_yweweler_25.wav
# Processed file 0_yweweler_26.wav
# Processed file 1_george_41.wav
# Processed file 0_lucas_49.wav
# Processed file 2_george_33.wav
# Processed file 7_jackson_7.wav
# Processed file 6_george_7.wav
# Processed file 1_theo_28.wav
# Processed file 1_theo_34.wav
# Processed file 9_yweweler_45.wav
# Processed file 9_theo_19.wav
# Processed file 0_jackson_26.wav
# Processed file 3_theo_31.wav
# Processed file 7_jackson_26.wav
# Processed file 3_lucas_31.wav
# Processed file 2_theo_28.wav
# Processed file 4_jackson_27.wav
# Processed file 8_theo_47.wav
# Processed file 6_theo_43.wav
# Processed file 7_jackson_46.wav
# Processed file 5_george_8.wav
# Processed file 2_theo_5.wav
# Processed file 8_jackson_2.wav
# Processed file 2_yweweler_43.wav
# Processed file 5_nicolas_17.wav
# Processed file 9_george_1.wav
# Processed file 4_lucas_37.wav
# Processed file 9_george_33.wav
# Processed file 3_theo_49.wav
# Processed file 7_lucas_30.wav
# Processed file 1_george_17.wav
# Processed file 7_nicolas_33.wav
# Processed file 3_theo_40.wav
# Processed file 0_theo_3.wav
# Processed file 4_theo_32.wav
# Processed file 6_jackson_21.wav
# Processed file 6_yweweler_38.wav
# Processed file 5_nicolas_5.wav
# Processed file 4_george_24.wav
# Processed file 7_lucas_27.wav
# Processed file 0_george_27.wav
# Processed file 5_yweweler_47.wav
# Processed file 7_theo_25.wav
# Processed file 1_theo_6.wav
# Processed file 1_theo_42.wav
# Processed file 8_lucas_13.wav
# Processed file 1_george_32.wav
# Processed file 1_yweweler_31.wav
# Processed file 4_jackson_30.wav
# Processed file 2_jackson_4.wav
# Processed file 4_lucas_36.wav
# Processed file 0_jackson_15.wav
# Processed file 9_jackson_45.wav
# Processed file 5_yweweler_16.wav
# Processed file 0_nicolas_3.wav
# Processed file 4_lucas_2.wav
# Processed file 8_jackson_25.wav
# Processed file 7_yweweler_0.wav
# Processed file 2_theo_16.wav
# Processed file 3_george_4.wav
# Processed file 5_jackson_10.wav
# Processed file 2_nicolas_40.wav
# Processed file 4_theo_14.wav
# Processed file 6_george_22.wav
# Processed file 1_lucas_17.wav
# Processed file 1_george_30.wav
# Processed file 2_jackson_44.wav
# Processed file 8_jackson_29.wav
# Processed file 3_theo_42.wav
# Processed file 4_george_2.wav
# Processed file 4_yweweler_46.wav
# Processed file 1_george_36.wav
# Processed file 1_nicolas_32.wav
# Processed file 0_theo_46.wav
# Processed file 2_yweweler_21.wav
# Processed file 6_george_33.wav
# Processed file 0_yweweler_41.wav
# Processed file 5_jackson_7.wav
# Processed file 4_theo_41.wav
# Processed file 3_lucas_14.wav
# Processed file 4_lucas_22.wav
# Processed file 0_yweweler_3.wav
# Processed file 2_yweweler_28.wav
# Processed file 9_george_38.wav
# Processed file 8_george_25.wav
# Processed file 2_jackson_33.wav
# Processed file 5_lucas_8.wav
# Processed file 1_nicolas_8.wav
# Processed file 4_theo_36.wav
# Processed file 3_jackson_4.wav
# Processed file 6_theo_17.wav
# Processed file 0_jackson_36.wav
# Processed file 0_nicolas_9.wav
# Processed file 6_yweweler_20.wav
# Processed file 3_george_16.wav
# Processed file 5_theo_13.wav

# %% [markdown]
# #Código

# %% [markdown]
# ##Data

# %%
def load_fsdd(spectrograms_path):
    x_train = []
    for root, _, file_names in os.walk(spectrograms_path):
        for file_name in file_names:
            file_path = os.path.join(root, file_name)
            spectrogram = np.load(file_path) # (n_bins, n_frames, 1)
            x_train.append(spectrogram)
    x_train = np.array(x_train)
    x_train = x_train[:, np.newaxis, :, :] # -> (3000, 256, 64, 1)
    return x_train

# %%
x_train = load_fsdd("/content/drive/MyDrive/Data_AudioGen/fsdd/spectrograms")

# %%
x_train = np.load("/content/drive/MyDrive/Data_AudioGen/fsdd/x_train_spectrograms.npy")

# %%
x_train.shape # (3000, 256, 64, 1)
# Out:
# (3000, 1, 256, 64)

# %%
np.save("/content/drive/MyDrive/Data_AudioGen/fsdd/x_train_spectrograms.npy",x_train)

# %%
class ImageDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image = self.data[idx]['image']
        label = self.data[idx]['label']
        if self.transform:
            image = self.transform(image)
        return image, label

# Define a transform to convert PIL images to tensors
stats = ((0.1307),(0.3081))
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(*stats,inplace=True)  # Convert PIL Image to PyTorch Tensor
])

# Update the datasets to use the transform
train_dataset = ImageDataset(ds['train'], transform=transform)
valid_dataset = ImageDataset(ds['test'], transform=transform)

# %%
Batch_size = 64

# %%
train_dl = DataLoader(x_train, batch_size=Batch_size, shuffle=True, num_workers=3, pin_memory=True)
valid_dl = DataLoader(x_train, batch_size=Batch_size, shuffle=False, num_workers=3, pin_memory=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# ##Check device

# %%
def get_default_device():
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')

def to_device(data, device):
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device

    def __iter__(self):
        for b in self.dl:
            yield to_device(b, self.device)

    def __len__(self):
        return len(self.dl)

# %%
device = get_default_device()
device
# Out:
# device(type='cpu')

# %%
device = get_default_device()
torch.cuda.empty_cache()
train_dl = DeviceDataLoader(train_dl, device)
valid_dl = DeviceDataLoader(valid_dl, device)

# %% [markdown]
# ##Base

# %%
def funcion_perdida(x, xrec, mu, logvar, alpha = 1000000):
  ecm = F.mse_loss(x, xrec, reduction='sum')
  kl = -0.5 * torch.sum(1 + logvar - mu**2 - logvar.exp())
  perdida = ecm + kl
  return perdida * alpha

# %%
class Base(nn.Module):

    def training_step(self, images):
        out, mu, log_variance = self(images)
        loss = funcion_perdida(images, out, mu, log_variance)
        return loss

    def validation_step(self, images):
        out, mu, log_variance = self(images)
        loss = funcion_perdida(images, out, mu, log_variance)
        return {'val_loss': loss.detach()}

    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()
        return {'val_loss': epoch_loss.item()}

    def epoch_end(self, epoch, result):
        print("Epoch [{}], train_loss: {:.4f}, val_loss: {:.4f}".format(epoch, result['train_loss'], result['val_loss']))

# %% [markdown]
# ##Model

# %%
class Encoder(nn.Module):
  def __init__(self,
                 input_shape,
                 conv_filters,
                 conv_kernels,
                 conv_strides,
                 latent_space_dim,
                 d_model):
    super(Encoder, self).__init__()
    self.layers = nn.ModuleList()

    in_channel = input_shape
    for out_channels, kernel_size, stride in zip(conv_filters,  conv_kernels, conv_strides):
        self.layers.append(nn.Sequential(nn.Conv2d(in_channel, out_channels, kernel_size, stride=stride, padding=1),
                                         nn.ReLU(),
                                         nn.BatchNorm2d(out_channels)))
        in_channel = out_channels

    self.bottleneck = nn.Flatten()
    self.mu = nn.Linear(d_model, latent_space_dim)
    self.log_variance = nn.Linear(d_model, latent_space_dim)

  def forward(self, x):
        for conv_layer in self.layers:
            x = conv_layer(x)
        x = self.bottleneck(x)
        return self.mu(x), self.log_variance(x)


class Decoder(nn.Module):
  def __init__(self,
                conv_filters,
                conv_kernels,
                conv_strides,
                latent_space_dim,
                d_model):
    super(Decoder, self).__init__()

    self.return_layer = nn.Linear(latent_space_dim, d_model)

    self.layers = nn.ModuleList()
    num_conv_layers = len(conv_filters)
    in_channels = conv_filters[num_conv_layers-1]

    for index in reversed(range(1, num_conv_layers)):
        index_output = index - 1
        out = 1
        if index == 4:
          out = (1,0)
        self.layers.append(nn.Sequential(nn.ConvTranspose2d(conv_filters[index], conv_filters[index_output], conv_kernels[index], stride=conv_strides[index], padding=1, output_padding=out),
                                         nn.ReLU(),
                                         nn.BatchNorm2d(conv_filters[index_output])))

    self.output_layer = nn.Sequential(nn.ConvTranspose2d(conv_filters[0], 1, conv_kernels[0], stride=conv_strides[0], padding=1, output_padding=1),
                                      nn.Sigmoid())

  def forward(self, x):
      x = self.return_layer(x)
      x = x.view(-1, 32, 8, 4)
      for convT_layer in self.layers:
          x = convT_layer(x)
      x = self.output_layer(x)
      return x

class VAE(Base):
  def __init__(self,
                input_shape,
                conv_filters,
                conv_kernels,
                conv_strides,
                latent_space_dim,
                d_model):
    super(VAE, self).__init__()
    self.encoder_step = Encoder(input_shape, conv_filters, conv_kernels, conv_strides, latent_space_dim, d_model)
    self.decoder_step = Decoder(conv_filters, conv_kernels, conv_strides, latent_space_dim, d_model)

  def proyectar(self, x):
    mu, logvar = self.encoder_step(x)
    std = torch.exp(0.5 * logvar)
    eps = torch.randn_like(std)
    z = mu + eps * std
    return z

  def forward(self, x):
    mu, logvar = self.encoder_step(x)
    std = torch.exp(0.5 * logvar)
    eps = torch.randn_like(std)
    z = mu + eps * std
    xrec = self.decoder_step(z)
    return xrec, z

# %%
in_chanel= 1
out_channels = (512, 256, 128, 64, 32)
Kernels = (3, 3, 3, 3, 3)
strides = (2, 2, 2, 2, (2,1))
letent_space = 128
d_model = 1024 # 7*7*64
model_ac = to_device(VAE(in_chanel, out_channels, Kernels, strides, letent_space, d_model), device)

# %% [markdown]
# ##Training

# %%
@torch.no_grad()
def evaluate(model_ac, val_loader):
    model_ac.eval()
    outputs = [model_ac.validation_step(batch) for batch in val_loader]
    return model_ac.validation_epoch_end(outputs)

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']
#metrics=[self._calculate_reconstruction_loss, self._calculate_kl_loss]
def try_model(epochs, lr, model, train_loader, val_loader, weight_decay=0, grad_clip=None, opt_func=torch.optim.SGD):
    torch.cuda.empty_cache()
    history = []

    optimizer = opt_func(model.parameters(), lr, weight_decay=weight_decay)

    sched = torch.optim.lr_scheduler.OneCycleLR(optimizer, lr, epochs=epochs, steps_per_epoch=len(train_loader))

    for epoch in range(epochs):

        model.train()
        train_losses = []
        outlist = []
        batchlist = []
        lrs = []

        for batch in train_loader:

            optimizer.zero_grad()
            loss = model.training_step(batch)
            train_losses.append(loss)

            loss.backward()

            if grad_clip:
                torch.nn.utils.clip_grad_value_(model.parameters(), grad_clip)

            optimizer.step()

            lrs.append(get_lr(optimizer))
            sched.step()

        result = evaluate(model, val_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        model.epoch_end(epoch, result)
        history.append(result)
    return history

# %%
#epochs = 100
#max_lr = 0.001
#grad_clip = 0.0001
#weight_decay = 1e-4
#opt_func = torch.optim.Adam

epochs = 150
max_lr = 0.01
grad_clip = 0.0001
weight_decay = 1e-4
opt_func = torch.optim.Adam

# %%
history = [evaluate(model_ac, train_dl)]
history
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:952: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv_transpose2d(
# [{'val_loss': 240865705984.0}]

# %%
history += try_model(epochs, max_lr, model_ac, train_dl, valid_dl,weight_decay, grad_clip,
                             opt_func=opt_func)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Epoch [0], train_loss: 66046369792.0000, val_loss: 24269238272.0000
# Epoch [1], train_loss: 12746536960.0000, val_loss: 11839048704.0000
# Epoch [2], train_loss: 9165429760.0000, val_loss: 9074173952.0000
# Epoch [3], train_loss: 8429403136.0000, val_loss: 7821793792.0000
# Epoch [4], train_loss: 7814683648.0000, val_loss: 7784536576.0000
# Epoch [5], train_loss: 7669081600.0000, val_loss: 7440054272.0000
# Epoch [6], train_loss: 7470108160.0000, val_loss: 7399279104.0000
# Epoch [7], train_loss: 7346086912.0000, val_loss: 6845946368.0000
# Epoch [8], train_loss: 7770352128.0000, val_loss: 7603406848.0000
# Epoch [9], train_loss: 7534089216.0000, val_loss: 8174123520.0000
# Epoch [10], train_loss: 6687391744.0000, val_loss: 6533010432.0000
# Epoch [11], train_loss: 6614190592.0000, val_loss: 6404699136.0000
# Epoch [12], train_loss: 6505620992.0000, val_loss: 6739302912.0000
# Epoch [13], train_loss: 6573998080.0000, val_loss: 7191192576.0000
# Epoch [14], train_loss: 6321093632.0000, val_loss: 6195986432.0000
# Epoch [15], train_loss: 6536634368.0000, val_loss: 5916332032.0000
# Epoch [16], train_loss: 8231973376.0000, val_loss: 9201938432.0000
# Epoch [17], train_loss: 8724889600.0000, val_loss: 10169800704.0000
# Epoch [18], train_loss: 7074489856.0000, val_loss: 8288256000.0000
# Epoch [19], train_loss: 6224345600.0000, val_loss: 6378114048.0000
# Epoch [20], train_loss: 9065132032.0000, val_loss: 7530228224.0000
# Epoch [21], train_loss: 6741630976.0000, val_loss: 6854139392.0000
# Epoch [22], train_loss: 5968144384.0000, val_loss: 6323741184.0000
# Epoch [23], train_loss: 6275716608.0000, val_loss: 7254835200.0000
# Epoch [24], train_loss: 6579221504.0000, val_loss: 11251090432.0000
# Epoch [25], train_loss: 6219681792.0000, val_loss: 6248690176.0000
# Epoch [26], train_loss: 5495766016.0000, val_loss: 9082368000.0000
# Epoch [27], train_loss: 5689275392.0000, val_loss: 6296404992.0000
# Epoch [28], train_loss: 5619336704.0000, val_loss: 7919112704.0000
# Epoch [29], train_loss: 6026829312.0000, val_loss: 6370537472.0000
# Epoch [30], train_loss: 6902722048.0000, val_loss: 13311129600.0000
# Epoch [31], train_loss: 7747726848.0000, val_loss: 19387637760.0000
# Epoch [32], train_loss: 7179563520.0000, val_loss: 8038415360.0000
# Epoch [33], train_loss: 7470950912.0000, val_loss: 9588368384.0000
# Epoch [34], train_loss: 8159459840.0000, val_loss: 9879471104.0000
# Epoch [35], train_loss: 8686733312.0000, val_loss: 10005953536.0000
# Epoch [36], train_loss: 9171103744.0000, val_loss: 8075759104.0000
# Epoch [37], train_loss: 9544534016.0000, val_loss: 8698442752.0000
# Epoch [38], train_loss: 8865011712.0000, val_loss: 7542027776.0000
# Epoch [39], train_loss: 7803567104.0000, val_loss: 8763419648.0000
# Epoch [40], train_loss: 7930477568.0000, val_loss: 10214927360.0000
# Epoch [41], train_loss: 8908030976.0000, val_loss: 9897290752.0000
# Epoch [42], train_loss: 9957107712.0000, val_loss: 10151306240.0000
# Epoch [43], train_loss: 8965045248.0000, val_loss: 8570575360.0000
# Epoch [44], train_loss: 8785814528.0000, val_loss: 10745127936.0000
# Epoch [45], train_loss: 9921471488.0000, val_loss: 10527138816.0000
# Epoch [46], train_loss: 10699638784.0000, val_loss: 12080786432.0000
# Epoch [47], train_loss: 8930514944.0000, val_loss: 8481118720.0000
# Epoch [48], train_loss: 7250387456.0000, val_loss: 9545473024.0000
# Epoch [49], train_loss: 7596763648.0000, val_loss: 8599689216.0000
# Epoch [50], train_loss: 8014606848.0000, val_loss: 13643128832.0000
# Epoch [51], train_loss: 8615256064.0000, val_loss: 9202551808.0000
# Epoch [52], train_loss: 8416779776.0000, val_loss: 8404648960.0000
# Epoch [53], train_loss: 7982257152.0000, val_loss: 7492218880.0000
# Epoch [54], train_loss: 7304912896.0000, val_loss: 8820645888.0000
# Epoch [55], train_loss: 7611202048.0000, val_loss: 8702951424.0000
# Epoch [56], train_loss: 8643570688.0000, val_loss: 13733483520.0000
# Epoch [57], train_loss: 9304851456.0000, val_loss: 9645922304.0000
# Epoch [58], train_loss: 9134551040.0000, val_loss: 8791250944.0000
# Epoch [59], train_loss: 8590548992.0000, val_loss: 8799477760.0000
# Epoch [60], train_loss: 8131808256.0000, val_loss: 20151773184.0000
# Epoch [61], train_loss: 7624331264.0000, val_loss: 9208379392.0000
# Epoch [62], train_loss: 7447954944.0000, val_loss: 12831044608.0000
# Epoch [63], train_loss: 7245050368.0000, val_loss: 7150618624.0000
# Epoch [64], train_loss: 7237684736.0000, val_loss: 7816414208.0000
# Epoch [65], train_loss: 7048605696.0000, val_loss: 9943711744.0000
# Epoch [66], train_loss: 7010108416.0000, val_loss: 6579375104.0000
# Epoch [67], train_loss: 7162832384.0000, val_loss: 6634931200.0000
# Epoch [68], train_loss: 7380274176.0000, val_loss: 8296157184.0000
# Epoch [69], train_loss: 7226112000.0000, val_loss: 8728130560.0000
# Epoch [70], train_loss: 7252781056.0000, val_loss: 7609770496.0000
# Epoch [71], train_loss: 6910401024.0000, val_loss: 6676216320.0000
# Epoch [72], train_loss: 6826828288.0000, val_loss: 15507303424.0000
# Epoch [73], train_loss: 6852971008.0000, val_loss: 8643206144.0000
# Epoch [74], train_loss: 6777737728.0000, val_loss: 6895412736.0000
# Epoch [75], train_loss: 6652492288.0000, val_loss: 11291452416.0000
# Epoch [76], train_loss: 6659419648.0000, val_loss: 6934611456.0000
# Epoch [77], train_loss: 6225194496.0000, val_loss: 9708038144.0000
# Epoch [78], train_loss: 7888658944.0000, val_loss: 7826306048.0000
# Epoch [79], train_loss: 7731942400.0000, val_loss: 7022474752.0000
# Epoch [80], train_loss: 7504921600.0000, val_loss: 7364286976.0000
# Epoch [81], train_loss: 5978776064.0000, val_loss: 11649166336.0000
# Epoch [82], train_loss: 6115227648.0000, val_loss: 6309201920.0000
# Epoch [83], train_loss: 6341664768.0000, val_loss: 9313200128.0000
# Epoch [84], train_loss: 6950187520.0000, val_loss: 10439050240.0000
# Epoch [85], train_loss: 7981803520.0000, val_loss: 9477002240.0000
# Epoch [86], train_loss: 8326725120.0000, val_loss: 10717125632.0000
# Epoch [87], train_loss: 8351301120.0000, val_loss: 25121738752.0000
# Epoch [88], train_loss: 7259962368.0000, val_loss: 11517301760.0000
# Epoch [89], train_loss: 7116467712.0000, val_loss: 10926985216.0000
# Epoch [90], train_loss: 8870324224.0000, val_loss: 6787851264.0000
# Epoch [91], train_loss: 7052532224.0000, val_loss: 8613327872.0000
# Epoch [92], train_loss: 7112480768.0000, val_loss: 9527031808.0000
# Epoch [93], train_loss: 7566019584.0000, val_loss: 8605463552.0000
# Epoch [94], train_loss: 7685940736.0000, val_loss: 10073768960.0000
# Epoch [95], train_loss: 5876681728.0000, val_loss: 5346603520.0000
# Epoch [96], train_loss: 5735938560.0000, val_loss: 6480028160.0000
# Epoch [97], train_loss: 5840175616.0000, val_loss: 5882844672.0000
# Epoch [98], train_loss: 5279988736.0000, val_loss: 5270249984.0000
# Epoch [99], train_loss: 5544355840.0000, val_loss: 7552459264.0000
# Epoch [100], train_loss: 6550420480.0000, val_loss: 7867024896.0000
# Epoch [101], train_loss: 6131846144.0000, val_loss: 5419689472.0000
# Epoch [102], train_loss: 6229293056.0000, val_loss: 6306782720.0000
# Epoch [103], train_loss: 5851052544.0000, val_loss: 5222915584.0000
# Epoch [104], train_loss: 6117188608.0000, val_loss: 8742350848.0000
# Epoch [105], train_loss: 6547429888.0000, val_loss: 6906874880.0000
# Epoch [106], train_loss: 5393292800.0000, val_loss: 14427486208.0000
# Epoch [107], train_loss: 5487953920.0000, val_loss: 4912881152.0000
# Epoch [108], train_loss: 4762558976.0000, val_loss: 4952303104.0000
# Epoch [109], train_loss: 4671011328.0000, val_loss: 4500130816.0000
# Epoch [110], train_loss: 4456306688.0000, val_loss: 5475243520.0000
# Epoch [111], train_loss: 4459006464.0000, val_loss: 4545646080.0000
# Epoch [112], train_loss: 4626969600.0000, val_loss: 4955129856.0000
# Epoch [113], train_loss: 4636394496.0000, val_loss: 5157345280.0000
# Epoch [114], train_loss: 4385297920.0000, val_loss: 5253826048.0000
# Epoch [115], train_loss: 4293767168.0000, val_loss: 4230526208.0000
# Epoch [116], train_loss: 4273303040.0000, val_loss: 4930461184.0000
# Epoch [117], train_loss: 4631284736.0000, val_loss: 8505033216.0000
# Epoch [118], train_loss: 4512261632.0000, val_loss: 4866771456.0000
# Epoch [119], train_loss: 4243911936.0000, val_loss: 5472403456.0000
# Epoch [120], train_loss: 4078991104.0000, val_loss: 5869890048.0000
# Epoch [121], train_loss: 4232395008.0000, val_loss: 6277819392.0000
# Epoch [122], train_loss: 4139564288.0000, val_loss: 4344603648.0000
# Epoch [123], train_loss: 4006256640.0000, val_loss: 5147574272.0000
# Epoch [124], train_loss: 4027332352.0000, val_loss: 4013462272.0000
# Epoch [125], train_loss: 4034481664.0000, val_loss: 4691089920.0000
# Epoch [126], train_loss: 3975735040.0000, val_loss: 3864383232.0000
# Epoch [127], train_loss: 4136600576.0000, val_loss: 4020596480.0000
# Epoch [128], train_loss: 3911372032.0000, val_loss: 3787283456.0000
# Epoch [129], train_loss: 3821732352.0000, val_loss: 4322163712.0000
# Epoch [130], train_loss: 3875357952.0000, val_loss: 3882104320.0000
# Epoch [131], train_loss: 3788165888.0000, val_loss: 3832855808.0000
# Epoch [132], train_loss: 3734884096.0000, val_loss: 3853883136.0000
# Epoch [133], train_loss: 3688644096.0000, val_loss: 3701117696.0000
# Epoch [134], train_loss: 3669960704.0000, val_loss: 4044122880.0000
# Epoch [135], train_loss: 3559279616.0000, val_loss: 3527161088.0000
# Epoch [136], train_loss: 3533711360.0000, val_loss: 3459674624.0000
# Epoch [137], train_loss: 3611720192.0000, val_loss: 3672517376.0000
# Epoch [138], train_loss: 3511614720.0000, val_loss: 3435192064.0000
# Epoch [139], train_loss: 3464059904.0000, val_loss: 3434789120.0000
# Epoch [140], train_loss: 3461020928.0000, val_loss: 3537862656.0000
# Epoch [141], train_loss: 3453020672.0000, val_loss: 3348660224.0000
# Epoch [142], train_loss: 3423497984.0000, val_loss: 3326406400.0000
# Epoch [143], train_loss: 3406009600.0000, val_loss: 3334072064.0000
# Epoch [144], train_loss: 3400531968.0000, val_loss: 3326744832.0000
# Epoch [145], train_loss: 3374225664.0000, val_loss: 3324346368.0000
# Epoch [146], train_loss: 3363226624.0000, val_loss: 3331475712.0000
# Epoch [147], train_loss: 3353721856.0000, val_loss: 3302594816.0000
# Epoch [148], train_loss: 3326629632.0000, val_loss: 3307192576.0000
# Epoch [149], train_loss: 3370477568.0000, val_loss: 3282884608.0000

# %%
save_path = "/content/drive/MyDrive/Data_AudioGen/weightsVAE_spectrogram.pth"
torch.save(model_ac.state_dict(), save_path)

# %% [markdown]
# ##Analysis

# %%
save_path = "/content/drive/MyDrive/Data_AudioGen/weightsVAE_spectrogram.pth"
weights = torch.load(save_path,map_location=torch.device('cpu'))

# %%
class MinMaxNormaliser:
    """MinMaxNormaliser applies min max normalisation to an array."""

    def __init__(self, min_val, max_val):
        self.min = min_val
        self.max = max_val

    def normalise(self, array):
        norm_array = (array - array.min()) / (array.max() - array.min())
        norm_array = norm_array * (self.max - self.min) + self.min
        return norm_array

    def denormalise(self, norm_array, original_min, original_max):
        array = (norm_array - self.min) / (self.max - self.min)
        array = array * (original_max - original_min) + original_min
        return array

# %%
class SoundGenerator:

    def __init__(self, vae, hop_length):
        self.vae = vae
        self.hop_length = hop_length
        self._min_max_normaliser = MinMaxNormaliser(0, 1)

    def generate(self, spectrograms, min_max_values):
        generated_spectrograms, latent_representations = self.vae(spectrograms)
        #generated_spectrograms = generated_spectrograms.numpy()
        signals = self.convert_spectrograms_to_audio(generated_spectrograms, min_max_values)
        return signals, latent_representations

    def convert_spectrograms_to_audio(self, spectrograms, min_max_values):
        signals = []
        for spectrogram, min_max_value in zip(spectrograms, min_max_values):
            log_spectrogram = spectrogram.numpy().reshape([256,64])
            denorm_log_spec = self._min_max_normaliser.denormalise(log_spectrogram, min_max_value["min"], min_max_value["max"])
            spec = librosa.db_to_amplitude(denorm_log_spec)
            signal = librosa.istft(spec, hop_length=self.hop_length)
            signals.append(signal)
        return signals

# %%
HOP_LENGTH = 256
SAVE_DIR_ORIGINAL = "/content/drive/MyDrive/Data_AudioGen/original"
SAVE_DIR_GENERATED = "/content/drive/MyDrive/Data_AudioGen/generated"
MIN_MAX_VALUES_PATH = "/content/drive/MyDrive/Data_AudioGen/fsdd/min_max_values.pkl"
SPECTROGRAMS_PATH = "/content/drive/MyDrive/Data_AudioGen/fsdd/spectrograms"

def load_fsdd(spectrograms_path):
    x_train = []
    file_paths = []
    for root, _, file_names in os.walk(spectrograms_path):
        for file_name in file_names:
            file_path = os.path.join(root, file_name)
            spectrogram = np.load(file_path) # (n_bins, n_frames, 1)
            x_train.append(spectrogram)
            file_paths.append(file_path)
    x_train = np.array(x_train)
    x_train = x_train[:, np.newaxis, :, :] # -> (3000, 256, 64, 1)
    return x_train, file_paths


def select_spectrograms(spectrograms,
                        file_paths,
                        min_max_values,
                        num_spectrograms=2):
    sampled_indexes = np.random.choice(range(len(spectrograms)), num_spectrograms)
    sampled_spectrogrmas = spectrograms[sampled_indexes]
    file_paths = [file_paths[index] for index in sampled_indexes]
    sampled_min_max_values = [min_max_values[file_path] for file_path in file_paths]
    return sampled_spectrogrmas, sampled_min_max_values


def save_signals(signals, save_dir, sample_rate=22050):
    for i, signal in enumerate(signals):
        save_path = os.path.join(save_dir, str(i) + ".wav")
        sf.write(save_path, signal, sample_rate)

# %%
model_ac.load_state_dict(weights)
# Out:
# <All keys matched successfully>

# %% [markdown]
# ##Generating audios

# %%
sound_generator = SoundGenerator(model_ac, HOP_LENGTH)

# %%
with open(MIN_MAX_VALUES_PATH, "rb") as f:
        min_max_values = pickle.load(f)
specs, file_paths = load_fsdd(SPECTROGRAMS_PATH)
sampled_specs, sampled_min_max_values = select_spectrograms(specs, file_paths, min_max_values, 5)
sampled_specs = DataLoader(sampled_specs, batch_size=5, shuffle=True, num_workers=3, pin_memory=True)

with torch.no_grad():
  signals, latent_space = sound_generator.generate(next(iter(sampled_specs)), sampled_min_max_values)
  original_signals = sound_generator.convert_spectrograms_to_audio(next(iter(sampled_specs)), sampled_min_max_values)
save_signals(signals, SAVE_DIR_GENERATED)
save_signals(original_signals, SAVE_DIR_ORIGINAL)

# %%
print("Original: sample 0")
Audio(original_signals[0], rate=22100)
# Out:
# Original: sample 0
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Generated: sample 0")
Audio(signals[0], rate=22100)
# Out:
# Generated: sample 0
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Original: sample 1")
Audio(original_signals[1], rate=22100)
# Out:
# Original: sample 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Generated: sample 1")
Audio(signals[1], rate=22100)
# Out:
# Generated: sample 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Original: sample 2")
Audio(original_signals[2], rate=22100)
# Out:
# Original: sample 2
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Generated: sample 2")
Audio(signals[2], rate=22100)
# Out:
# Generated: sample 2
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Original: sample 3")
Audio(original_signals[3], rate=22100)
# Out:
# Original: sample 3
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Generated: sample 3")
Audio(signals[3], rate=22100)
# Out:
# Generated: sample 3
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Original: sample 4")
Audio(original_signals[4], rate=22100)
# Out:
# Original: sample 4
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Generated: sample 4")
Audio(signals[4], rate=22100)
# Out:
# Generated: sample 4
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ##Using the latent space for the generation of samples

# %%
with torch.no_grad():
  _, latent_space = sound_generator.generate(next(iter(sampled_specs)), sampled_min_max_values)

# %%
original_signals = sound_generator.convert_spectrograms_to_audio(next(iter(sampled_specs)), sampled_min_max_values)

# %%
def generate_random_numbers(min_value, max_value, std_value, count):
    mean_value = (min_value + max_value) / 2
    random_numbers = np.random.normal(loc=mean_value, scale=std_value, size=count)
    clipped_numbers = np.clip(random_numbers, min_value, max_value)
    return clipped_numbers

random_latent = []
for i in range(5):
  min_value = latent_space[i].min()
  max_value = latent_space[i].max()
  std_value = latent_space[i].std()
  count = 128
  random_numbers = generate_random_numbers(min_value, max_value, std_value, count)
  random_latent.append(random_numbers.to(torch.float32))

# %%
random_latent = torch.stack(random_latent)

# %%
with torch.no_grad():
  signals_random = model_ac.decoder_step(random_latent)

# %%
signals_rand = sound_generator.convert_spectrograms_to_audio(signals_random, sampled_min_max_values)

# %%
print("Original: sample 0")
Audio(original_signals[0], rate=22100)
# Out:
# Original: sample 0
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Generated: sample 0")
Audio(signals_rand[0], rate=22100)
# Out:
# Generated: sample 0
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Original: sample 1")
Audio(original_signals[1], rate=22100)
# Out:
# Original: sample 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Generated: sample 1")
Audio(signals_rand[1], rate=22100)
# Out:
# Generated: sample 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Original: sample 2")
Audio(original_signals[2], rate=22100)
# Out:
# Original: sample 2
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Generated: sample 2")
Audio(signals_rand[2], rate=22100)
# Out:
# Generated: sample 2
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Original: sample 3")
Audio(original_signals[3], rate=22100)
# Out:
# Original: sample 3
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Generated: sample 3")
Audio(signals_rand[3], rate=22100)
# Out:
# Generated: sample 3
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Original: sample 4")
Audio(original_signals[4], rate=22100)
# Out:
# Original: sample 4
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Generated: sample 4")
Audio(signals_rand[4], rate=22100)
# Out:
# Generated: sample 4
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
